# %%
import os
import fitz

# %%
def extract_questions_and_reviews_from_pdf(pdf_path):
    TERM = "(Spring 2024)"

    pdf_data = {}
    pdf_data["questions"] = {}

    try:
        with fitz.open(pdf_path) as pdf:
            for page in pdf:
                text = page.get_text()
                lines = text.splitlines()

                line_idx = 0
                while line_idx < len(lines):
                    line = lines[line_idx]
                    
                    if TERM in line:
                        pdf_data["course_name"] = line
    
                    elif "Instructor: " in line:
                        pdf_data["instructor"] = line.split("Instructor: ")[1]

                    elif "Subject: " in line:
                        pdf_data["subject"] = line.split("Subject: ")[1]
    
                    elif "Catalog & Section: " in line:
                        pdf_data["course_number"] = line.split("Catalog & Section: ")[1].split(" ")[0]

                    elif "Course ID: " in line:
                        pdf_data["crn"] = line.split("Course ID: ")[1]

                    elif "Q: " in line:
                        question = line.split("Q: ")[-1]
                        reviews = []

                        line_idx += 1
                        while line_idx < len(lines):
                            if lines[line_idx].isnumeric():
                                skip_idx = 1
                                while lines[line_idx + skip_idx] == "":
                                    skip_idx += 1
                                    
                                reviews.append(
                                    lines[line_idx + skip_idx]
                                )

                                line_idx += skip_idx
                            elif "Q: " in lines[line_idx]:
                                break
                            else:
                                line_idx += 1

                        pdf_data["questions"][question] = reviews
                        continue
                    
                    line_idx += 1
                        
    except Exception as e:
        print(f"An error occurred: {e}")

    return pdf_data

# %%
# Path to the uploaded PDF file
pdf_file_path = './data/39696.pdf'

# Extract questions and reviews
pdf_data = extract_questions_and_reviews_from_pdf(pdf_file_path)
pdf_data
# Out:
# {'questions': {'What were the strengths of this course and/or this instructor?': ['Prof. Maryam is very good at explaining how data structure works. But for the coding part ( c language), we need to spend more time on ourselves.',
#    'She is very accommodating to her students. She listens to feedback and ensures the students are in a good learning environment. She is very caring towards her class and shows excellent interpersonal',
#    'The instructor is very enthusiastic and explains concepts very well. She is also very interactive and engaging. It was difficult to keep the class attentive for 3 hours, but she was very good at making it',
#    "She is very kind and provide a lot help for us, I like her class. She let us join the discussion in canvas in each class, which ensure everyone's engagement. She also has sense of humor.",
#    'Maryam is so patient and detail-oriented, and she shows every step of logic process in solving problems as she explains, and she always prepares a lot materials beforehand and she even prepares the',
#    'clear logic for every class, and have full notes provided for every class',
#    'Expressive and informative teaching.',
#    'Enthusiasm and passion for teaching, Professionalism in C and data structures, Efficiency in class time management.',
#    'Maryam delivers exceptional lectures! She explains complex concepts very effectively, certainly much better than tutorial videos on YouTube. She prepares and shares detailed Jupyter notes with us,',
#    'Maryam is really a fantastic teacher; her lectures are excellent, and the course materials are very detailed. I like her very much.',
#    'Maryam makes the best notes',
#    'always explain material in detail.',
#    'The lecture is clear,',
#    'make things easy to understand',
#    'The instructor is serious about teaching, so she is well-prepared with easy-understanding explanations,',
#    'Well prepared. Start from 0 and can learn a lot.'],
#   'What could the instructor do to make this course better?': ["This course should be more specific on one area of date structure, algorithm, or computer system. But it only touches every aspect of above three topic. It is not the lecturer's responsibility to change the",
#    'There is a lot of information in this course and it is difficult to master it all. Having more focused homework would help isolate some topics rather than grouping some together.',
#    "I think the course is very well structured! I don't have any other feedback.",
#    "small things: changing take-home final to in class in person one, works for me but lead to my classmates' complaints",
#    'Maybe more challenge homework.',
#    "Maryam is the best professor ever I could know. If there's any chance, could our Silicon Valley campus have her for the CS5800 Algorithm in a future semester? I'm gonna register in the first place. She is",
#    'Increasing the frequency and detail of personalized feedback on assignments and projects could help us identify our strengths and areas for improvement more clearly.',
#    '"Everything is very good already. Could you please instruct in the 5800 course for future summer/fall/spring/winter semesters? Whether it\'s at the SV campus or online, just as long as we, the SV students,',
#    "I think there's nothing that needs improvement; it's already very good.",
#    'Be more organized',
#    'should give students more homework to practice, and explain more C programming',
#    'Give some in-person office hours.',
#    'keep it',
#    'The class content is not well organized. Learning C with data structure and algorithm without a clear stage divided will make the learning not as clear as expected.',
#    'Online session is great hope to have more online sessions.'],
#   'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['The instructor created an engaging and inclusive environment.',
#    'She can focus on difficult part more, skip those easy part.',
#    "There's nothing to improve. She always communicate with us from class and after class from survey. During this semester, he made at least 3-4 surveys to learn what we want to learn for the next course,",
#    'Maryam is the best teacher I have ever seen in NEU. She made full preparation for every class, every definition, examples and little exercise. She has her own notes for every part of the module.',
#    'Adaptability and flexibility in the teaching approach, recognizing and accommodating the unique needs and learning styles of individual students. Open and welcoming attitude towards all students,',
#    'Again, all very good already. I like the instructor uses Teams so students can share resources and students questions can be answered so others can get the solution too.',
#    "Maryam's teaching pace is very good; it allows people to concentrate, and the three-hour class feels very quick. Moreover, her method of explaining knowledge is great, and I can easily understand the key",
#    'Good at teaching, but not good at course organization and logistics. Too often students ran into technical difficulties while accessing online discussions and tests.',
#    'always love and respect students',
#    'The instructor is very patient in explaining knowledge.',
#    'NA',
#    "can be more challenging, don't need to make class too easy just because of a few students who think that's too hard.",
#    'Very clear structures but could give more deep contents.'],
#   'Please comment on your experience of the online course environment in the open-ended text box.': ['There were a few times that we used Zoom for class.',
#    'Very good! ',
#    'Very good ',
#    'I like that the lectures were recorded. ',
#    'Maryam used the Jupyternotebook, which I like. ',
#    "Good! Maryam always shows her clear hand-writing notes on ipad and share the screen. It's as effective as an on-site course! ",
#    'Great ',
#    'n/a ',
#    'Very great structured and teach step by step ',
#    'I think online course is a great method to recall my memory on Lecture ',
#    "Maryam, thanks for being a great instructor for this course. You are kind and always open to students' question. ",
#    'Good and helpful! '],
#   'What I could have done to make this course better for myself.': ['Review class notes more',
#    'Review all the recording after classes and practice leetcode questions!',
#    'Practice active recall more by redoing the coding assignments',
#    'I wish I had kept up with the modules along with the lectures, but the lectures were easy to follow even without them.',
#    'Maybe learn C language with more practice.',
#    'I could review more materials including recordings of class and the shared notes to remember better the knowledge!',
#    'keep it',
#    'n/a',
#    'Do more reviews.',
#    'The course schedule is sometimes off the syllabus.',
#    'I could have explored websites and journals for self-studying and attended office hours more often.']},
#  'course_name': 'Data Str, Algo App in CmpSys (Spring 2024)',
#  'instructor': 'Farahmand Asil, Maryam',
#  'subject': 'CS',
#  'course_number': '5008',
#  'crn': '39696'}

# %%
pdf_data["questions"].keys()
# Out:
# dict_keys(['What were the strengths of this course and/or this instructor?', 'What could the instructor do to make this course better?', 'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.', 'Please comment on your experience of the online course environment in the open-ended text box.', 'What I could have done to make this course better for myself.'])

# %%
len(
    pdf_data["questions"]
    ["Please comment on your experience of the online course environment in the open-ended text box."]
)
# Out:
# 12

# %%
import os
import logging
import fitz

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
)

class TraceDataScraper:
    def extract_questions_and_reviews_from_pdf(self, pdf_path):
        """
        Extracts structured data, including questions and their reviews, from a PDF.

        Parameters:
            pdf_path (str): The file path of the PDF file.

        Returns:
            dict: A dictionary containing extracted data such as course details and questions with reviews.
        """

        TERM = "(Spring 2024)"  # Term identifier to filter course-specific data
        pdf_data = {}
        pdf_data["questions"] = {}

        try:
            # Open the PDF using fitz (PyMuPDF)
            with fitz.open(pdf_path) as pdf:
                for page_number, page in enumerate(pdf, start=1):
                    text = page.get_text()  # Extract text from the page
                    lines = text.splitlines()  # Split text into lines

                    line_idx = 0
                    while line_idx < len(lines):
                        line = lines[line_idx]

                        if TERM in line:
                            pdf_data["course_name"] = line

                        elif "Instructor: " in line:
                            pdf_data["instructor"] = line.split("Instructor: ")[1]

                        elif "Subject: " in line:
                            pdf_data["subject"] = line.split("Subject: ")[1]

                        elif "Catalog & Section: " in line:
                            pdf_data["course_number"] = line.split("Catalog & Section: ")[1].split(" ")[0]

                        elif "Course ID: " in line:
                            pdf_data["crn"] = line.split("Course ID: ")[1]

                        elif "Q: " in line:
                            question = line.split("Q: ")[-1]
                            reviews = []

                            line_idx += 1
                            while line_idx < len(lines):
                                if lines[line_idx].isnumeric():
                                    skip_idx = 1
                                    while lines[line_idx + skip_idx] == "":
                                        skip_idx += 1

                                    reviews.append(lines[line_idx + skip_idx])

                                    line_idx += skip_idx
                                elif "Q: " in lines[line_idx]:
                                    break
                                else:
                                    line_idx += 1

                            pdf_data["questions"][question] = reviews
                            continue

                        line_idx += 1

        except Exception as e:
            logging.error(f"An error occurred while processing the PDF {pdf_path}: {e}")

        return pdf_data

    def process_directory(self, data_directory):
        """
        Processes all PDF files in the given directory and consolidates review information.

        Parameters:
            data_directory (str): The path to the directory containing PDF files.

        Returns:
            dict: A dictionary containing consolidated data for all PDF files.
        """
        logging.info(f"Starting to process directory: {data_directory}")
        consolidated_data = {}

        try:
            # Iterate through all files in the directory
            for filename in os.listdir(data_directory):
                if filename.endswith(".pdf"):
                    crn = filename.split(".pdf")[0]  # Extract CRN from filename

                    pdf_path = os.path.join(data_directory, filename)

                    # Extract data from the PDF
                    pdf_data = self.extract_questions_and_reviews_from_pdf(pdf_path)
                    consolidated_data[crn] = pdf_data

        except Exception as e:
            logging.error(f"An error occurred while processing the directory {data_directory}: {e}")

        logging.info(f"Completed processing of directory: {data_directory}")
        return consolidated_data

# Example Usage
data_scraper = TraceDataScraper()
data_directory = "./data"
consolidated_reviews = data_scraper.process_directory(data_directory)
# consolidated_reviews
# Out:
# 2024-12-26 20:13:01,656 - INFO - Starting to process directory: ./data
# 2024-12-26 20:13:12,616 - INFO - Completed processing of directory: ./data

# %%
consolidated_reviews
# Out:
# {'35056': {'questions': {'What were the strengths of this course and/or this instructor?': ['Timing and Canvas are Organized.',
#     'very responsive professor',
#     'Passionate, knowledgeable, extremely accommodating.',
#     'Scott was a pleasure to have as a professor! I can tell that he really enjoys what he is teaching us, and that enthusiasm is contagious. He is very approachable and flexible, and makes it abundantly clear that',
#     'Assignments (homework, labs), and live lectures were very helpful and interesting.',
#     'He is enthusiastic about the material which helps to make it more interesting.',
#     'Very responsive to student questions and very, very nice attitude',
#     'Very responsible and passionate about teaching. I think he offered us great help and some mental support',
#     'We can understand the points deeply through several kinds of teaching approaches.',
#     'The strengths of this course include lots of contents and interactive lessons, while the instructor excelled in clear communication, fostering an engaging learning environment.'],
#    'What could the instructor do to make this course better?': ['Modify the presentation assignment. A bit too open ended which led to topics that were really big and not digestible in a presentation. More importantly, they took up too much class time.',
#     'Despite his infectious enthusiasm and the clarity with which he delivers his lectures, the 3 hour long form lecture is tough. If these lectures were delivered as twice weekly 90 minute sessions it would be',
#     "The lectures were good, I didn't feel overly compelled by most of the online videos and I felt like I learned more from the live lectures, the homework assignments, and the supplementary reading. One of the",
#     'The instructional design misses the mark for me and my learning style. This feedback is based on what works/could work for me. Take with a grain of salt. The class time is largely lecture with out any',
#     'None',
#     'Nothing that i could think of',
#     'The instructor could enhance the course by incorporating more examples.'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['This course is very dense - there is a TON of material to work through, and it is not necessarily intellectually easy stuff either. I think any instructor would struggle to cram all of this into a single semester, and',
#     'Prof. Valcourt has a very clear and comprehensive way of describing difficult content. While this course was intellectually challenging, I never remained stuck for too long and I learned a lot along the way.',
#     "Scott's passion makes it fun. There were topics that I thought I would never have any interest in but do feel curious about now because of his enthusiasm. He is very welcoming and generally creates a",
#     'None',
#     'The instructor explains things well but could improve by using more examples and slowing down a bit.'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['Excellent ',
#     'very good ',
#     'Videos are always hit or miss for me. I thought these were a good collection for the course. ',
#     'The video resources were better in 5008 than 5004, but they were still a slog. I found the videos that I could code along with way more useful than those that were just explaining concepts.',
#     "I'm currently living in multiple places and spending lots of time in different parts of Maine. For this reason, it's been difficult to attend in person although I try to as often as I can. Often with hybrid classes, it's",
#     'I was mostly present in person. ',
#     'The teacher is very good, very nice and the lessons are great! ',
#     'The class atmosphere is very relaxed and the professor is very friendly ',
#     'The online course environment is easy to use and helps me learn effectively. '],
#    'What I could have done to make this course better for myself.': ['study more',
#     'Spend less time worrying about my IDE and just use VSCode! I wasted a LOT of time going down VIM rabbit holes, which while interesting, were largely useless. Similarly, my time management was absolutely',
#     'More time to read additional content resources and keep up with the module videos.',
#     'Maybe a little C syntax in advance.',
#     'Practice more coding with C or C instead of Python when going through Leetcode Questions',
#     'It is particularly benefit for doing leetcode problems in the future.',
#     'I can utilize the additional resources provided to enhance my understanding of the course material.']},
#   'course_name': 'Data Str, Algo App in CmpSys (Spring 2024)',
#   'instructor': 'Valcourt, Scott',
#   'subject': 'CS',
#   'course_number': '5008',
#   'crn': '35056'},
#  '40380': {'questions': {'What were the strengths of this course and/or this instructor?': ['Lino is a nice person to work with, I totally agree that and I consider him like friends or colleagues. He is warm and kind.',
#     'They are extremely helpful and friendly.',
#     'lino is humorous',
#     'Lino is very kind and considerate!',
#     'The instructor was enthusiastic and willing to help.',
#     "1. Lino is a very nice person, but I won't say I learnt much from this course, we only covered the basic ideas during the lecture, which are far more simpler than the module materials. And it's hard to say that I",
#     'No',
#     'Very knowledgeable, clear that he knows his stuff.',
#     'Lino is direct and helpful, he is not verbose in terms of explanation, but he is always on the point and makes it clear.'],
#    'What could the instructor do to make this course better?': ['It would be better if we could have something other than the outline and bullet points from the online modules. Like breaking down some difficult part into small pieces, or use some simple examples to',
#     "Teach more stuff not covered by the module videos. Since we've already watched those videos, there is no need to repeat those things. Also, please share more industrial experiences, for example, when did",
#     'i hope lino can provide the "model answer" of each assignments.',
#     'Reduce the number of homework and labs.',
#     'Provide more detailed rubric and instructions for the homeworks, labs and final projects.',
#     'better assignment description.',
#     'More interactive activities with the class to really help us understand the material.',
#     'Cannot think about anything at this moment'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['The class exercises are good, but few students pay attention to them so the overall experience does not meet the expectation. I do not think there would be much to do for the instructor, but this problem',
#     "Lino is quite easygoing and considers students' feelings a lot.",
#     'no. wordy.'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['Some modules of the online courses are not very organized. In specific weeks, there are too much content and many chapters in one module. In other weeks, there are just a few chapters and we could',
#     'Some videos on Canvas do not explain things well. I hope those videos can be replaced. ',
#     "The online materials of this course is quite lengthy and boring, it's really hard to follow. The instructor JohnPark love to mix metaphors that don't really help understanding in his explanation. ",
#     "Terrible, trash assginment instruction which leading to hundreds of hours wasting on understaing prof's purpose. ",
#     'It was learning through videos online along with quizzes. The videos were a bit long but the descriptions underneath were pretty good. ',
#     'Some of the online classes are not understandable, thinking about module 4. ',
#     'The online course material is badly organized. It is not helpful at all, only making the learning experience terrible. ',
#     'Online materials are not perfectly well-organized. Some videos are too long and difficult to follow '],
#    'What I could have done to make this course better for myself.': ['More information about the OOD structure.',
#     'read all the materials provided and schedule meetings during office hours',
#     'Make a schedule for daily study.',
#     'Self-learn the topic covered in this course before this semester, and using other online materials other than the module videos.',
#     'nope',
#     "Instead of watching the videos, I could've just read the descriptions underneath. Often times, I found the videos quite lengthy as I could've read the descriptions in a much shorter time.",
#     'Read more extra resources in Java']},
#   'course_name': 'Object-Oriented Design (Spring 2024)',
#   'instructor': 'Coria Mendoza, Lino',
#   'subject': 'CS',
#   'course_number': '5004',
#   'crn': '40380'},
#  '39593': {'questions': {'What were the strengths of this course and/or this instructor?': ['Laney is probably the best professor when it comes to explaining difficult materials so that students can understand.',
#     'Passion',
#     'The teaching of concepts was usually really good',
#     'Laney was enthusiastic, friendly, helpful, and full of energy. She made a very difficult course a lot of fun.',
#     "Dr. Strange is a lovely human being, and I truly enjoyed having her as my instructor. She is passionate in what she teaches, and is fully invested into us as students. She's reassuring, and the kind of instructor",
#     'Great instructor, very enthusiastic',
#     'Laney was one of the best teachers I have ever had. She explained new topics very well and with patience. She always made sure that everyone in the class understood what se was saying.',
#     'Professor taught each and every concepts well and even the course pacing was good.',
#     'Great teacher/personality.',
#     "She takes her time when explaining and doesn't move on unless everyone gets it, and is very responsive to questions both inside and outside of class.",
#     'I think the homework was structured in a way that really made us think deeply about the problem. Even though the questions were not easy i learned a lot as a result and have a great understanding.',
#     '1. Clear logic.',
#     "I really enjoyed Laney's teaching style. I like how she goes over the main ideas of a topic and then delves into multiple examples to really clarify the topic.",
#     'Honestly everything. Teaching style, ethusiasm, and just overall knowledge. Elena was extrememly knowledgeable and great as a professor.',
#     'Professor Laney was always on time and open to answering all questions I had throughout the semester.',
#     'The professor was amazing. She was very prepared for every lecture and explained the material clearly. She was energetic and engaged during lectures. Useful homework assignments that challenged',
#     'Laney broke down the concepts very clearly using simple real life examples that made topics easy to digest and understand! As someone who is intimidated by math, she made me realize that math can be',
#     'NA',
#     'The professor gave excellent and vivid lectures, and the learning process was enjoyable.',
#     'Laney can explain everything very clearly, step by step. This course introduces basic math for CS, and covers many topics with their basic ideas.'],
#    'What could the instructor do to make this course better?': ['Some topic in homework was not discussed in the lecture.',
#     'Easier homeworks lol. The homeworks sometimes felt like they were really difficult compared to what we were learning in class.',
#     'Professor Laney was amazing, just continue doing what she is doing.',
#     'Nothing. Its great. Maybe earlier lectures! Its hard to pay attention at 9pm at night.',
#     "I believe she's doing a fantastic job, but perhaps incorporating examples in class that closely align with the homework problems could enhance students' understanding of how to tackle the more challenging",
#     'NA'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['Passion',
#     'Again, Dr. Strange is a STRONG instructor, who is a great professor for this very intellectually demanding course. Other than not having tutors, I truly feel that this course was enjoyable despite how hard it',
#     'Some more practice problems like the practice problems for the exam would be useful. The ICAs are too easy and dont provoke us to really learn a new concept. Harder practice problems with solutions',
#     'I would like to think that everyone in this course felt safe and encouraged to ask questions or participate in discussions. It was an inclusive learning environment.',
#     '-',
#     'Really open to any questions.',
#     'They did a great job explaining things. I learned a lot!',
#     "N/A for the level of the course it was honestly superb teaching and I probably would have not passed the course if it wasn't for Elena's amazing teaching.",
#     'Professor Laney was amazing and always listened to students questions and answered them in a timely and respectful manner.',
#     "I can't emphasize enough how great the professor was. She explained concepts so well, provided outstanding examples, kept students engaged thru hands-on examples. Provided plenty of online",
#     '-',
#     'NA',
#     'The lectures were well organized, with many vivid examples, and the assignments are set reasonably to make students grasp the key points.'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['great. ',
#     'Class was 99% in person, but Piazza for out-of-class stuff was great. ',
#     'Great course website. ',
#     'OVERALL THE BEST MATH CLASS IVE TAKEN THUS FAR IN MY COLLEGE CAREER ',
#     'Professor Laney was always open to answering any questions that I had. ',
#     "We didn't have asynchronous classes so I cannot comment on this ",
#     'I love professor Laney ',
#     'the course was great. '],
#    'What I could have done to make this course better for myself.': ['Be more self-displine',
#     'I think I could have spent a bit more time on a couple homework’s',
#     'Not go on vacation during it. Ask for help more regularly.',
#     'I feel that I could have done a better job on our homework. Even though I did not fail any of the homework, I certainly could have gotten better grades on them in the beginning of the semester.',
#     'Studied longer and more often',
#     'I am satisfied with what I have done.',
#     'Study more.',
#     'I could have practiced more',
#     '-',
#     'Continued studying a particular unit or module even after we moved on. Found myself having to do a lot of repeat review after getting rusty on stuff.',
#     'i should have focused on keeping up with the homework, but due to my work schedule i would sometimes let it get ahead of me and opt for turning in the homework late.',
#     'giving myself more time to get through the homework and also attend more TA hours.',
#     'I wish I had utilised my time appropriately to do my homework and submit on time',
#     'Nothing.',
#     'Having consistent study sessions all throughout the semester',
#     'NA']},
#   'course_name': 'Discrete Structures (Spring 2024)',
#   'instructor': 'Strange, Elena',
#   'subject': 'CS',
#   'course_number': '5002',
#   'crn': '39593'},
#  '39704': {'questions': {'What were the strengths of this course and/or this instructor?': ['It helps you get a deeper understanding of some key concepts in object oriented programming.'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['great '],
#    'What I could have done to make this course better for myself.': ['Start the lab earilier.']},
#   'course_name': 'Recitation For CS 5010 (Spring 2024)',
#   'instructor': 'Cheng, Zhuoqun',
#   'subject': 'CS',
#   'course_number': '5011',
#   'crn': '39704'},
#  '21104': {'questions': {'What were the strengths of this course and/or this instructor?': ['Enthusiasm, very knowledgable on the subject, very skilled, very passionate about teaching, in class coding and fixing bugs',
#     'Amazing humor. Very knowledgable. Amazing programming skills. Live coding was very helpful.',
#     'very good',
#     'TA and professor were open to help. The project were the main way of learning in this course.',
#     'Instructor is very passionate about course and making it useful and practical. He makes you feel like he cares for your personal and career success which is invaluable in a professor, and the project based',
#     'The course/ professor provides a very efficient and interactive way to encourage student to dive into the class which makes me always absorbing a lot in class.',
#     'Good communication',
#     'humur',
#     'Very funny, enthusiastic, and knowledgeable. I love his style as a person',
#     "John's course is very informative and I can learn a lot. He's a passionate professor who really want his students to learn something.",
#     'Useful and interesting.',
#     'One of the biggest strengths of this course was the requirement to finish a lot of projects. I learnt the most from struggling and trying to finish the project. I felt very accomplished when I completed the',
#     'excellent',
#     'The professor was very accommodating with deadlines and giving us adequate time to understand specific topics. The course is content-heavy so having more time to understand/implement concepts',
#     'The knowledge that professor has and the enthusiasm as well makes you to learn more.',
#     'Live coding'],
#    'What could the instructor do to make this course better?': ['Use class time better, I feel like only the first 20 and the last 40 minutes of class time were useful, we spent a lot of time sidetracked on non-important things',
#     'Make the lottery more fair I guess. Some people didnt get a turn for 3-4 classes.',
#     'when doing the living coding, slow down a little bit',
#     'Everything was good, but sometimes as a beginner coder I felt like I was expected to know so much so fast.',
#     'Sometimes the strengths come to the cost of organization. I enjoyed the idea of the recorded mid term and the lottery, but the lack of communication over the mid term made scheduling stressful. I also',
#     'I think the professor really did a great work already',
#     'Make deadlines longer and make some changes to make up for the project.',
#     'Sometimes, the class can be quite stressful for introverted individuals like myself.',
#     'He is a bit unorganized',
#     "Sometimes the course is way too informative and it's a little bit overwhelming. Also, sometimes the concept is way too deep and I cannot really understand and easily lost. I hope the learning curve can be",
#     'N/A',
#     "The only thing I feel like is that there's too much materials but too little time for the course. It would have been better if we can become more specialized in some areas.",
#     'N/A',
#     'I feel like this class covered too much, which makes me feel like I have a surface-level understanding of these concepts. It would be helpful to maybe divide lectures into portions where topics are broken',
#     'Maybe give more time to complete projects..haha.',
#     'Requirements and deadlines of assignments are not clear enough.'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['Very inclusive in all aspects, probably the professor that cares about inclusivity the most so far I have seen',
#     'He is very friendly, but I kind of hope the assignments are not so infrequent but big (we pretty much just have 4 massive projects and almost nothing else). I hope we had more lightweight projects and less',
#     'everything is good',
#     'Loved the attitude! I liked coming to class.',
#     'Overall well, appreciated him mentioning he was learning Chinese',
#     'Show more cases related to the web development.',
#     'The professor use the lottry and tweet to encourage student to preview all the material before class to have better overview for the knowledge points.',
#     'N/A',
#     'Professor John is very supportive. Some improvements could be that some rubrics may not be very clear to understand when we have the project. Teamwork does not achieve the goal of learning',
#     'While class was helpful, sometimes it felt like the projects had nothing to do with what we had covered so far. Connecting to Mongo and implementing CRUD was taught after that project was due. Same with',
#     'Sometimes, the class can be quite stressful for introverted individuals like myself.',
#     'Live coding is very helpful to me because this course is all about getting to work,'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['N/A ',
#     'Canvas was very helpful in storing all the lecture recordings and showing assignment instructions for me ',
#     'very good ',
#     'The course environment was great. I was always able to talk to peers and TA when I had question about a topic or project. ',
#     'Overall the instructor is very knowledgeable and engaging, some of the online organization is a little scattered and ambiguous (some materials in his personal website, some in Canvas..., or no specific dates',
#     'Feels good about the course! I hope more case study could be included in this course. ',
#     'The course materials prepared by the professor for the web development course were exceptional in terms of both quality and relevance. Each module was meticulously designed with a clear focus on',
#     'There is no online course materials ',
#     'I am not a fan of the lottery thing but it did help me concentration sometimes. ',
#     "This class was a like a rollercoaster ride in itself. If you really want to learn ins and out of web development, Professor John's class is a great start. It challenges you to learn more things which are used in the",
#     'I like the use of Slack '],
#    'What I could have done to make this course better for myself.': ['Do more readings.',
#     "better time management. Some weeks were loaded with heavy project assignments and some weeks I didn't do much. The week of deadline for projects are usually extremely painful and full of struggles",
#     'practice more',
#     'I think i planned my weeks better juggling work ad school I think I would have been more prepared for class. The weekly readings took a lot of time but were very useful in learning.',
#     'More diligence on the readings and requesting office hours',
#     'To find more tutorial resource to learn deeper.',
#     'I should prepare and preview the material deeper before the class and focus on the questions in class.',
#     'Probably need to some samples to work on the project.',
#     'I think dedicating more time to doing non-assigned reading would have helped me understand the smaller, more detailed topics that could help with projects.',
#     'I should have taken this course early when I start the program.',
#     'Space out the work on projects instead of working on them only the week before ddl.']},
#   'instructor': 'Guerra Gomez, John Alexis',
#   'subject': 'CS',
#   'course_number': '5610',
#   'crn': '21104'},
#  '21188': {'questions': {'What were the strengths of this course and/or this instructor?': ['good'],
#    'What could the instructor do to make this course better?': ['good',
#     'The readme file of the team activity is somehow hard to read. Takes extra time to figure out what it intends to say.'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['good'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['good ',
#     'I think the experience of this class is not so good as Cs 5001, cecause group cooperation and discussion on the Internet make everyone less involved compared offline. '],
#    'What I could have done to make this course better for myself.': ['good',
#     'Maybe I can be more active during the group disscussion.']},
#   'instructor': 'Lionelle, Albert',
#   'subject': 'CS',
#   'course_number': '5003',
#   'crn': '21188'},
#  '40181': {'questions': {'What were the strengths of this course and/or this instructor?': ['Professor Mullen is able to explain concepts very clearly, and takes time to discuss with students if there is anything that is unclear.',
#     'Professor Tony Mullen demonstrates attentive teaching, ensuring the class grasps concepts thoroughly. His passion for teaching shines through as he carefully guides us through materials at a deliberate',
#     'The instructor prepare for the course well and even used a 3D printed models to illustrate the linked list concept.',
#     'I love Tony!',
#     'Professor Mullen was easily relatable, understanding, and it feels like he enjoys teaching. I typically always looked forward to coming to this class because I feel like I always got something out of it.',
#     'He was aware that were new to computer science and was able to teach effectively because of it'],
#    'What could the instructor do to make this course better?': ['I think when using Processing towards the end of the course, it is imperative for the instructor to give a better overview of the debugging process. I think giving a more detailed overview of the fact that',
#     'Provide classwork or homework that encourages student collaboration.',
#     'The workload for this course is too high in the perspective of homework and weekly lab. Is hard for students with zero to minimum coding experience to have time to review and have deep understanding of',
#     "it's the best already",
#     'I think possibly introducing paired programming exercises for lab days where to practice, one person would be a navigator and the other would be the driver. Then switching halfway through. Whenever I',
#     'Maybe find time to go over assignments with the leftover time at the end of class'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['I think Professor Mullen did a great job with the challenge of teaching people with different backgrounds and coding experience. I do think for absolute beginners, this would be a very challenging course. It',
#     'In terms of inclusive learning, Professor Tony Mullen exhibits strengths by fostering a supportive environment where all students feel valued and engaged. He could further enhance inclusivity by assigning',
#     'Instructor doing great in building an inclusive learning environment. I think the homework and lab workload will be the only part can be improved.',
#     'nothing',
#     'The class was a good level of challenging for people with no comp-sci backgrounds. I do think that the demos could be more complex. We would do really basic demos for the topic of the week, but when we',
#     'He was great at communicating to the class what he was doing. He also facilitated a class where asking questions is encouraged'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['I thought the online materials (canvas, piazza, etc.) were very well organized. I liked how the syllabus each week clearly outlined the lecture topics and optional textbook readings. ',
#     'good experience ',
#     'We utilized Piazza in this course. However，I would recommend a virtual office hour each week with the instructor will be a plus for this course. ',
#     'very good ',
#     'N/A ',
#     'Piazza was very helpful for asking questions and getting answers in a timely manner '],
#    'What I could have done to make this course better for myself.': ['I think starting assignments early, attending office hours, and discussing with classmates was key to doing well in this course.',
#     'spending more time on practicing',
#     'Spend more time in this course in the very beginning of the course.',
#     'nothing',
#     'Time management. It was difficult to balance two classes with the high standard for what is needed to pass and have unexpected events in my personal life come my way.',
#     'Managed my time a little better by not getting hung up on bugs longer than I should without asking for help']},
#   'course_name': 'Intensive Foundations of CS (Spring 2024)',
#   'instructor': 'Mullen, Anthony',
#   'subject': 'CS',
#   'course_number': '5001',
#   'crn': '40181'},
#  '39538': {'questions': {'What were the strengths of this course and/or this instructor?': ['The lessons always prepared us well for the homework and assessments, unlike other classes.',
#     "Flex time to answer students' questions online",
#     'nicely organized',
#     'Nothing good',
#     'The instructor in on time in handing out lecture materials and homework. Grading is done on time.',
#     'homework was clearly explained'],
#    'What could the instructor do to make this course better?': ['Have 1 or 2 more coding assignments to practice establishing a network.',
#     'Extra homework examples would be helpful.',
#     'go deeper on network',
#     'I doubt that Ali have enough ability to organize a useful course',
#     'There could be a live session with the instructor from time to time. The instructor depends too heavily on the slides and does not elaborate on concept sufficiently. Some times his read the slides which make',
#     'more lecture'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['Always took care to provide extra explanations and practice on the more complicated concepts.',
#     'Before midterm and final exam, always provide sample test and solution to students for practice.',
#     'I really like this course',
#     'N/A',
#     "There could be a weekly recitation where lecturer quickly run through a summary on the weeks' content and provide some challenging examples and engage in Q&A with students.",
#     'it was 1 hour per week and it feels like learning by yourself with barely any use of the instructor'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['Well organized. I always knew what I needed to complete for the week and even had space to read ahead for next week. ',
#     'Module videos and examples are helpful. Great learning experience. ',
#     'very nice course and the professor is very supportive ',
#     "This course didn't teach anything useful which anyone undergraduate student could finish this course. ",
#     "There's no live session with lecturer. Few TA I talked to are not helpful and knowledgable on the topic. ",
#     'homework was not greatly challenging however it was not so clear on the material he is teaching ',
#     'Great! ',
#     'The modules are well organized and TA office hours are plentiful. '],
#    'What I could have done to make this course better for myself.': ['Attend more office hours.',
#     'Spent more time on module learning.',
#     'find myself a partner to study together',
#     'Change the instructor as he teach nothing.',
#     'Attend TA session for more TA and see if they are knowledable.',
#     'attend more office hours',
#     'Use other online materials such as GeeksForGeeks and YouTube to better understand the material.',
#     'Nothing']},
#   'instructor': 'Sharifian Attar, Ali',
#   'subject': 'CS',
#   'course_number': '5700',
#   'crn': '39538'},
#  '20303': {'questions': {'What were the strengths of this course and/or this instructor?': ['Clear communication, responsive, and great at teaching',
#     'instructor was well prepared and knowledgeable'],
#    'What could the instructor do to make this course better?': ['A more define rubric for the final project will be helpful to filter the topics, but otherwise really great class!',
#     'slight change need to be done is have project milestones , so at each stage evaluation will be better for final result.'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['Syllabus has good pace and flexibility is key (instructor understands our struggle and needs).',
#     'NA'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['I am rating online experience based on Slack experience ',
#     'it was very helpful; '],
#    'What I could have done to make this course better for myself.': ['Taking it earlier in my master journey will be more helpful',
#     'Its very effective , no need any changes']},
#   'instructor': 'Aguiar, Everaldo',
#   'subject': 'CS',
#   'course_number': '6220',
#   'crn': '20303'},
#  '17350': {'questions': {'What were the strengths of this course and/or this instructor?': ['He is so patient and nice, and he is so cute, I love him so much!',
#     'The instructor clearly is excited about the material and excited to be teaching this particular course. The course felt reasonably thorough.',
#     'The course unfolded in a way that felt very approachable as someone coming from a humanities background.',
#     'He is nice and supportive.',
#     'Coding format and basics are enhanced thoroughly and the professor is humorous and inspiring',
#     'Dr Bagley was incredibly enthusiastic and positive when teaching the subject material. I feel like his energy was very important as some subjects regarding computer science could be very dry',
#     'Open to questions and gave a good foundation in CS and some experience in python. (Meant to write food foundations in cs and Math for Discrete',
#     "One of the strengths of this course is that it really is made for people who have zero experience in coding. Although it's really challenging, it can be done.",
#     'The instructor is kind and strict',
#     "This Python course has taught me so much about coding fundations. And after doing the homeworks, I have learned a lot about coding styles which I hadn't paid much attention to. Professor Keith is very",
#     'Enthusiasm and understanding that all students do not have a code background.',
#     'This course forces students to have good coding habits, and it also gives some practical strategies on how to program to solve problems. Many of my problems in self-taught learning were cleared taking this',
#     'Strengths of course: good foundation for our future career in CS. We learned a lot of very important topics.',
#     "Sometimes it's really struggled when you coding or messed up on the exam but the professor gives us a lot of practices for students to improve which is helpful.",
#     'He is extremely approachable person and he has excellent explanations are engaging',
#     'The instructor did a great job of explaining the real world applications of the topics covered in class. He also did a great job of easing us into harder concepts.',
#     'carefully in details , understand the painpoint for aligners.',
#     '/',
#     'Good'],
#    'What could the instructor do to make this course better?': ['I think we can have more stressful practice',
#     '/',
#     'Good'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['He is good at talking about the concepts in a really simple way that make us really easy to understand',
#     'I think the professor was pretty good at this.',
#     'Prof Keith is good at answering student questions and breaking down big topics into more easily understandable chunks.',
#     'overall good',
#     'N/A',
#     "Keep adding more practical (real world examples) pieces to this course. I do not enjoy purely theoretical courses without talking about real world cases. This course's strength is keeping everything practical",
#     'The syllabus could include information on how to attend if you have to miss class. Additionally, it should state the importance of Gradescope and the method we are submitting code and being graded.',
#     'I have none, he was an excellent professor for this course',
#     'The instructor did a great job of allowing everyone to participate.',
#     'N/a',
#     '/',
#     'Prof Bagley was amazing but some of the TAs were not. Early in the semester, I made a regrade request on a homework and after review, my grade was dropped 5 points lower. This seemed punitive and',
#     'Good'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['My interactions with classmates were either in person or over text ',
#     'good ',
#     '/ ',
#     'Good '],
#    'What I could have done to make this course better for myself.': ['i would preview the python as much as possible before start taking this course.',
#     'I had a pretty good time overall.',
#     'Prepare in advance and do homework immediately after publication',
#     'i could have spent more on it.',
#     'Read the instructions carefully and when doing assignments and exams. I lose lots of points on being careless on fulfilling the instructions.',
#     'I could for more practice and meet with TA’s more often. Hovewer the experience that I got from this class will help me for upcoming semesters',
#     'Read the lecture notes before classes',
#     'Although this course is designed for students who have no previous coding experience, having learned some beforehand would have made it easier for me. I could have gotten ahead at the start, as some of',
#     'Good enough',
#     'Consistent Practice',
#     'Could have practiced more in this course, but the math course kept me busy already.',
#     "Kept up with the assignments that were optional. Although optional, I now know that means we won't be graded on them but it's very important to learning the information and succeeding in the course.",
#     'No',
#     '/',
#     'Good']},
#   'instructor': 'Bagley, Keith',
#   'subject': 'CS',
#   'course_number': '5001',
#   'crn': '17350'},
#  '33587': {'questions': {'Please comment on the strength and/or weakness of the required textbook/course materials.': ['The completion of a working compiler each week was integral to this course. I do not believe that I would have had nearly as much motivation or debugging ability otherwise.',
#     'There weren\'t a lot of materials available, and I got one of the "recommended" books which ended up being pretty unhelpful',
#     'this class *** rules',
#     'Amazing course website. Very thorough lectures with great examples. Would be nice for the "Do Now" examples in the lectures to either line up more with the homework, or to be completely disjoint with the',
#     'Ben Lerner is not using traditional textbooks because he is taking his own approach to teaching Compiler Design. However, this is because he is (rightfully) unhappy with the way many textbooks teach the',
#     'The assignments were really solid until tuples were introduced. Obviously the course is still being developed, but it was very frustrating it being in such an incomplete state.',
#     'Working without a textbook was fine, but it only worked well when the lecture notes were posted online. Towards the end of the semester, this stopped happening which was challenging.',
#     "Didn't really use the textbooks, but they contain useful information",
#     'The book was not really required. Class notes posted by professor were more than sufficient.',
#     'The lecture notes were generally good. There were some holes, but obviously they will improve after this semester. For the most part they were thorough and clear, and helped me understand a lot of',
#     'Lecture notes were a very helpful reference for assignments.'],
#    'Please comment on the strengths of this course and/or ways to improve this course.': ['Spread out the work load , it seemed too much in the beginning and middle of semester and really nothing in the ending month.',
#     'The material was very interesting, and the structure of starting with a basic functional compiler and expanding it, instead of going phase-by-phase was a fantastic approach.',
#     'I think that the format of this course was excellent and greatly helped me understand the importance of the different phases of a compiler. Some of the assignments were a little rough around the edges',
#     "Hardest class I've taken but I still love it so much",
#     "Compilers is always going to be a difficult course with a large time requirement. But Ben's approach to the class made what should have been a hard class into a never-ending nightmare of constant work.",
#     'Learning the material and completing the homework in just a week is usually an unreasonable task unless you choose to forgo any activities outside of schoolwork for the entire semester.',
#     'Overall, very good course. Like stated in class, it was the first iteration of the course, so a little here and there, but a good solid course that taught a lot of really good and interesting concepts.',
#     "I really enjoyed this course and found it to be one of the most challenging I've ever taken. It was a lot more work than I think a class should be though (sometimes 30 hours/week). One thing I think could be"],
#    "Describe instructor's strengths, areas for improvement, and any additional comments.": ['feel the blern',
#     'Ben is a great lecturer but could do better at listening to students and providing feedback during office hours.',
#     'Great professor, knows the material really well and teaches it really well.',
#     "Prof Lerner is always prepared, knows what he's talking about and is always available to meet with students."]},
#   'instructor': 'Lerner, Benjamin',
#   'subject': 'CS',
#   'course_number': '6410',
#   'crn': '33587'},
#  '40983': {'questions': {'What could the instructor do to make this course better?': ['When I was choosing this course, I asked several seniors about this course, and many people suggested that I take it because the content of this course is very important. However, the content of this'],
#    'What I could have done to make this course better for myself.': ['We need to learn a lot by ourselves, and the content of this course is of little significance.']},
#   'course_name': 'Scalable Distributed Systems (Spring 2024)',
#   'instructor': 'Chen, Yeh-cheng',
#   'subject': 'CS',
#   'course_number': '6650',
#   'crn': '40983'},
#  '40406': {'questions': {'What were the strengths of this course and/or this instructor?': ['The course content is very detailed, and the teacher teaches well. This is a course where we can learn a lot of mobile-related knowledge. really nice!',
#     "She will answer your questions very patiently, even if your questions are very easy. But please don't copy her code, she will get angry.",
#     'Neda is very professional and I like the course experience with her each week. I learned a lot.',
#     'Step by step instruction in class.'],
#    'What could the instructor do to make this course better?': ['no',
#     "I think it's pretty good.",
#     "Nothing. It's very good."],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['really like this course!',
#     "I think it's pretty good."],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['all good ',
#     "It was great to attend the course in person. Because in class, in addition to the teacher's explanation, the teaching assistant will also help you modify the code. ",
#     'All resources are useful and help me save a lot of time. '],
#    'What I could have done to make this course better for myself.': ['having a certain understanding of React and JavaScript',
#     'You need to arrange your time reasonably. The workload of the final project will be very large, and you need enough energy and time to complete it. If you want it to be a work that can be published instead of']},
#   'course_name': 'Mobile Application Development (Spring 2024)',
#   'instructor': 'Changizi, Neda',
#   'subject': 'CS',
#   'course_number': '5520',
#   'crn': '40406'},
#  '19943': {'questions': {'What were the strengths of this course and/or this instructor?': ['Communication skills and teaching skills in general',
#     'examples and execrises in the class.',
#     'very kind and skillful in teaching',
#     'the online notes are well organized，and the course provides an important foundation for the future imtermediate courses.',
#     'The instructor is nice and helpful, hope the class time can be more reasonable not too late of the day, and in class time can be used more efficiently',
#     'The lectures clearly explained the required match concept in general. In class exercise and questions help students understand the problems better',
#     'This instructor provides clear course notes.',
#     'The professor made everything clear.',
#     'Professor is very nice.',
#     'clear explanation and well designed structure',
#     'Good explanation,',
#     'kind knowledgeable'],
#    'What could the instructor do to make this course better?': ['Encouraging students to make a group of different people each time.',
#     'no',
#     'make less homework',
#     'more lively example, interaction',
#     "I would appreciate if the lecture notes are in print form rather than hand writing if that's not too much trouble to type. Just get tired to read hand writing notes when there are more than 2 pages.",
#     'Thank you for everything even if you were in difficult times! I hope the world will be back in peace and love again very soon!',
#     "it's already the best.",
#     'Everything was all good !!!',
#     'now is the best'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['give more online resources',
#     '.',
#     'I think giving the students options to attend the lectures in person or online is great, also online workshop is good. Since we have back to back courses from Monday to Thursday in spring 2024, if the work',
#     'This instructor provides clear course notes. I can learn extra knowledge from reading the notes.',
#     'good enough',
#     'strengths: interactive, patient',
#     'Everything was good',
#     'no need to improve'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['I guess online class was challenging to attend because I don’t feel connections with other students and the instructor. ',
#     'It was amazing. She takes feedback and acts on it. ',
#     'Online course content is very informative and helpful ',
#     'Online course is flexible, for some contents which involve inductions, calculations etc., online course would not be the most efficient way of study. The online problem workshop is good. I am grade that',
#     'Course materials are uploaded ',
#     "It's really helpful. ",
#     'The class is really good. ',
#     'best teacher '],
#    'What I could have done to make this course better for myself.': ['Read the materials from professior',
#     'have more online courses',
#     'watch the vedio before the class',
#     'Maybe delve deep into real-world application of concepts every Friday.',
#     'If "I" means the student, I would go through all the notes and watch the online courses in advance',
#     'Thank you, Maryam!',
#     'Browse the online materials in advance.',
#     'read the metarial before the class',
#     'Spend more time studying the course and watching online videos each time before coming to class to be fully prepared to the lecture',
#     'attend more office hours',
#     'best me']},
#   'instructor': 'Farahmand Asil, Maryam',
#   'subject': 'CS',
#   'course_number': '5002',
#   'crn': '19943'},
#  '35075': {'questions': {'What were the strengths of this course and/or this instructor?': ["The professor really makes an effort to engage with his students. He uses literally every second of our allotted time together as effectively as possible. He's very knowledgeable about the subject, willing to",
#     'Professor M. is fantastic! He knows his subject, and he genuinely cares about his students learning, not just checking a box for doing the class. He will help as much as you need him to.',
#     'Professor clearly loves the material and his excitement is contagious. He knows it all very well.',
#     'Instructor is extremely knowledgable in the subject of algorithms. Very cordial and professional.',
#     'Clarity in his lectures',
# ...
#     'The schedule was set quite well. Assignments/Modules were released in time. The Professor is quite understanding and kept the class quite active even though the class strength was high. Glad I took a',
#     'Great instructor! Probably the best I had in this university so far. Glad to have him as my prof!',
#     "This isn't on the professor but the TAs should give better feedback on the homework. Any feedback we received for our project came from the professor and it was so helpful. He really knows the field really",
#     'Well prepared',
#     'The instructor prepares every course very well and the contents are useful and attracting. This course made me better understand that we need to design a thing to be more user-friendly, and not always',
#     'Instructor was very witty, and taught the class with a lot of enthusiasm and skill. Instructor was always available to answer questions, and really helped students.',
#     'Excellent teaching skills. The syllabus, type of coursework, interactive classes, wide breadth of knowledge, humor everything made the course very interesting.',
#     'Great instructor',
#     'Fun instructor',
#     'The professor was humorous and generally engaging.',
#     'A lot of HCI content and applying it to a semester-long project was a good idea- felt very natural. Definitely a good introduction into the world of modern UI design, I feel. As someone with only a casual',
#     'Good content.'],
#    'What could the instructor do to make this course better?': ['Instructions were frequently vague, and violated the UX principles taught in this class:',
#     'Maybe set expectations a little bit sooner, at times I felt like there was a disconnect between how long the professor thought activities/assignments would take us vs. how long they actually did. This was',
#     'The course load was a bit hectic after the initial weeks. We were investing more than 10 hrs each week on FP deliverables. I was in my last semester so was kind of hectic for me. So decreasing the course'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['The professor was very good and informed about the course. And very helpful.'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['It was good, Piazza was a great resource for asking questions (quick responses) and the professor effectively used Canvas. Lecture slides, assignments, and other resources were posted there throughout',
#     'Good enough! '],
#    'What I could have done to make this course better for myself.': ['I could have planned a bit and reached out to professor more on my doubts.',
#     'Read the optional reading materials',
#     'I think the deliverables are too many, professor compensated it by dropping the lowest scores, which is good.',
#     'Spent more time',
#     'Build more prototypes to get to know Axure.',
#     'Nothing.',
#     'Learn more about Axure RP before the class.',
#     'Accomdative TA',
#     "I could've spent more time researching about the concepts of HCI, outside the bounds of the course, enabled by what I had learned within the course scope.",
#     'I did my best',
#     'more come to class and finish everything before the due.',
#     "Taken some notes during lectures, although slides were provided. I feel if I'd taken some notes it would've easier for me to revisit once the classes were done.",
#     'Maybe seeking out additional material such as the Google UX certification course videos to gain a broader scope and be a more self-sufficient learner.',
#     'I could have taken this course during my previous semesters where I had more time to devote.',
#     'Nothing much, it was best.',
#     'more colabs',
#     'Being more wise in choosing my project team mates.',
#     "Maybe prepare a better work environment for the final project. I don't know why I cannot install the tool we use on my PC but on my Laptop.",
#     'Nothing. It;s good',
#     'I like the course design. The workload is too high in the final week.',
#     'Read more reading.',
#     'Worked earlier on projects probably.',
#     'Been more transparent when I felt a member of my group was slacking a little bit.',
#     'The course was not challenging. Biggest challenge is managing time and staying ahead of assignments as there is much assignments not hard but take time',
#     'Review the course content/slides routinely',
#     'The course was perfectly structured. I learnt a lot through perfect does of content, instruction, and clarification.',
#     'NA',
#     'Start on the project earlier',
#     'General advice for this course- there are a lot of assignments and it will really help if you stay on top of them, not waiting to submit them all at the last minute (because often multiple are due the same day).',
#     'I think having a background a bit in HCI would have been good. Later in the course, we saw much time being invested apart from the lectures.']},
#   'instructor': 'Yildirim, Caglar',
#   'subject': 'CS',
#   'course_number': '5340',
#   'crn': '15055'},
#  '39674': {'questions': {'What were the strengths of this course and/or this instructor?': ["Extremely attentive and understands students' need",
#     'Communication, Passion.',
#     'professional, patient, brilliant, very nice',
#     'Professor is so kins and helps us to follow him step by step',
#     'Good at communicating and breaking down concepts',
#     'The instructor is alwanys very patient and he teaches us very clearly with step by step design and thinking',
#     'Professor Nadim Saad teaches very carefully.'],
#    'What could the instructor do to make this course better?': ['Nothing I can think of',
#     'Keep maintain his passion',
#     'Give more assignments and practices',
#     'Unsure',
#     'Add more coding problem-solving cases in class'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ["Extremely attentive and understands students' need",
#     'So great',
#     'Unsure',
#     'nothing, a perfect instructor. Hope that I can take more classes of him'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['materials reflect on lectures ',
#     'Professor Nadim, always adapt the class even we have classes online. ',
#     'perfect ',
#     'Excellent ',
#     'N/A '],
#    'What I could have done to make this course better for myself.': ['Nothing I can think of for now',
#     'Practicing more has been challenging, especially with the number of festive days coinciding with our class schedule.',
#     'Do projects',
#     'Spent 1-2 more hours a week',
#     'having more problem-solving sections in class']},
#   'course_name': 'Intensive Foundations of CS (Spring 2024)',
#   'instructor': 'Saad, Nadim',
#   'subject': 'CS',
#   'course_number': '5001',
#   'crn': '39674'},
#  '40219': {'questions': {'What were the strengths of this course and/or this instructor?': ['Everaldo is the best! Seriously, one of the best professors at NEU Seattle.',
#     'Best professor I have ever met throughout the whole program. I learned a lot from the professor.',
#     'Instructor is very knowledgable in his field of Data Science and his real-world experience helps me decide that this is not the career I want to dive in.',
#     'Constructive feedback, well-prepared materials, flexibility, unique humor, high efficiency in replying the message, excellent time management.',
#     'The instructor made the class very fun!'],
#    'What could the instructor do to make this course better?': ['He should teach more courses :)',
#     'Add more course stuff about building ML application and ML infra.',
#     'More interactive activities in class after lecture since there is plenty of time for class activities after lecture.',
#     'Teach a bit more challenging topics'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ["Super approachable and easy to communicate with. He explains things clearly and creates a great atmosphere for learning. I didn't just take the class, I truly enjoyed it. Thank you!",
#     'prepare detailed guide for configuration, clear and meaningful',
#     'He is very considerate and helpful all the time, and he even gave me some insights about if or not to pusue a phd degree.',
#     'This is my second Data Mining course at NEU, and I glad I took it. Everaldo is super experienced, sophisticated, and professional. This course has helped me learn Data Mining in depth.'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['Very smooth and amazing '],
#    'What I could have done to make this course better for myself.': ['do more personal coding to learn in the first half of the semester since mostly is theory.']},
#   'course_name': 'Data Mining Techniques (Spring 2024)',
#   'instructor': 'Aguiar, Everaldo',
#   'subject': 'CS',
#   'course_number': '6220',
#   'crn': '40219'},
#  '10630': {'questions': {'What were the strengths of this course and/or this instructor?': ['Good'],
#    'What could the instructor do to make this course better?': ['Good'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['Good'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['Good '],
#    'What I could have done to make this course better for myself.': ['Good']},
#   'instructor': 'Dym, Brianna',
#   'subject': 'CS',
#   'course_number': '5011',
#   'crn': '10630'},
#  '40184': {'questions': {'What were the strengths of this course and/or this instructor?': ['I think our instructor did a good job of providing a lot of resources and additional problems for students to understand the course material. It is also clear that she cares about her students success, as she',
#     'Professor Sarita excelled in providing clear examples and solving problems in class. While her in-class examples are easy to follow, the difficulty level of her homework and exams/quizzes surpasses that of',
#     "I don't know where exactly the strengths were. I came to lecture to get introduced to the topics, then I'd go home or find a place to study and pretty much just google lessons and watch youtube videos for"],
#    'What could the instructor do to make this course better?': ['I think the Canvas course could be organized better. For example, having more details about corresponding Zybook chapters alongside what each lecture day will cover would be helpful. I also think having',
#     'In each lesson, Professor Sarita adeptly introduces examples and thoroughly explores the subject matter during the initial portion of class. However, the latter part often feels rushed, lacking the same depth',
#     'The optional reading material should be required.'],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ["I think our instructor's strength was providing support to students who needed it. I appreciated the extra resources and additional practice problems, Zybook, and other online materials. I also appreciated",
#     'Professor Sarita effectively presents material and examples, promoting inclusivity. However, she could improve by ensuring equal attention to all lesson parts and providing clearer course materials.',
#     'I think what I said about the book was enough.'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ['I think the online course environment (specifically Canvas modules) could be organized more carefully. However, I did appreciate having all the resources provided by our professor. I thought the Zybook',
#     'The online courses including the Zybook was difficult to learn from. ',
#     'N/A '],
#    'What I could have done to make this course better for myself.': ['Previewing course content on Zybook and going through practice problems was important for me.',
#     'Not sure what I could have done personally because during the course, I feel like I really pushed myself to get through it. However, I do know there was a two day class that was suppose to prepare us, but I']},
#   'course_name': 'Discrete Structures (Spring 2024)',
#   'instructor': 'Singh, Sarita',
#   'subject': 'CS',
#   'course_number': '5002',
#   'crn': '40184'},
#  '35062': {'questions': {'What were the strengths of this course and/or this instructor?': ['This course really helped solidify many concepts w/ Object Oriented Design, and design paradigms in general. Prof. Domino was very enthusiastic about the material and cared about student outcomes.',
#     'flexible',
#     'The strengths of this course include extensive content and interactive lessons, while the instructor excelled in clear communication, fostering an engaging learning environment.',
#     'Molly was fantastic at making sure she was available for studies should the need anything. She always comes to class excited to teach.',
#     'help to clarify some confusion when taking online courses.'],
#    'What could the instructor do to make this course better?': ['Minor adjustments to pacing and formatting of lectures could make some of the concepts easier, but this was already improved by the second half of the semester.',
#     'please organize canvas',
#     "Rehearse lectures beforehand. Explain what she is doing and why she is doing it. Don't code fast during lecture.",
#     'The instructor could enhance the course by incorporating more examples.',
#     'Organizing the assignment panel page at the beginning of the semester would be helpful.',
#     'iron out any further issues with canvas',
#     "I'm able to ask questions anytime in class."],
#    'Please expand on the instructor’s strengths and/or areas for improvement in facilitating inclusive learning.': ['Prof. Domino cared about including everyone in the class discussions, and actively worked to solicit feedback and participation from students who were less vocal.',
#     'update canvas. get rid of outdated info. update syllabus, update projects.',
#     'The instructor explains things well but could improve by using more examples and slowing down a bit.',
#     'For OOD, we may need more information in a macro approach rather than details in practice.'],
#    'Please comment on your experience of the online course environment in the open-ended text box.': ["The online lecture materials were good and helped me solve a lot of problems in assignments I couldn't initially answer. Prof. Domino provided clarification and additional comments on many of the online",
#     'canvas is outdated with a lot of irrelevant information. ',
#     'I did not like the "This week in 5004" page. It frequently disagreed with the assignment due dates and did not always include every assignment. I was often confused about what was due on which dates. I',
#     'Totally, it is really useful. ',
#     'The online course environment is easy to use and helps me learn effectively. ',
#     "I feel it's okay ",
#     'Canvas was a bit unorganized at the start, but she got it cleaned up ',
#     'For OOD, online course may need more structure introduction. When showing code, it may need show which class we are in, since sometimes I will get lost. '],
#    'What I could have done to make this course better for myself.': ['Viewed all the online materials a week ahead to be prepared for lecture; this is difficult w/ full time work, though.',
#     'Get a better understanding of algorithms before coming in.',
#     'Studied more before class so that I could follow the lecture.',
#     'watch vedios and books ahead may be better.',
#     'I can utilize the additional resources provided to enhance my understanding of the course material.',
#     'Spent more time outside of course hours review the course material',
#     'do some reading for reference materials.']},
#   'course_name': 'Object-Oriented Design (Spring 2024)',
#   'instructor': 'Domino, Molly',
#   'subject': 'CS',
#   'course_number': '5004',
#   'crn': '35062'}}

# %%
import pandas as pd

def json_to_dataframe(consolidated_data):
    """
    Converts the JSON output from the TraceDataScraper into a pandas DataFrame.

    Parameters:
        consolidated_data (dict): The JSON data output from the TraceDataScraper.

    Returns:
        pd.DataFrame: A pandas DataFrame containing the structured data.
    """
    # Create a list to hold structured data
    rows = []

    for crn, course_data in consolidated_data.items():
        course_name = course_data.get("course_name", "")
        instructor = course_data.get("instructor", "")
        subject = course_data.get("subject", "")
        course_number = course_data.get("course_number", "")
        questions = course_data.get("questions", {})
        
        # Iterate over questions and reviews
        for question, reviews in questions.items():
            for review in reviews:
                rows.append({
                    "CRN": crn,
                    "Course Name": course_name,
                    "Instructor": instructor,
                    "Subject": subject,
                    "Course Number": course_number,
                    "Question": question,
                    "Review": review
                })

    # Create DataFrame from rows
    dataframe = pd.DataFrame(rows)
    return dataframe

df = json_to_dataframe(consolidated_reviews)
df
# Out:
#          CRN                                 Course Name       Instructor  \
# 0      35056  Data Str, Algo App in CmpSys (Spring 2024)  Valcourt, Scott
# 1      35056  Data Str, Algo App in CmpSys (Spring 2024)  Valcourt, Scott
# 2      35056  Data Str, Algo App in CmpSys (Spring 2024)  Valcourt, Scott
# 3      35056  Data Str, Algo App in CmpSys (Spring 2024)  Valcourt, Scott
# 4      35056  Data Str, Algo App in CmpSys (Spring 2024)  Valcourt, Scott
# ...      ...                                         ...              ...
# 12657  35062        Object-Oriented Design (Spring 2024)    Domino, Molly
# 12658  35062        Object-Oriented Design (Spring 2024)    Domino, Molly
# 12659  35062        Object-Oriented Design (Spring 2024)    Domino, Molly
# 12660  35062        Object-Oriented Design (Spring 2024)    Domino, Molly
# 12661  35062        Object-Oriented Design (Spring 2024)    Domino, Molly
#
#       Subject Course Number  \
# 0          CS          5008
# 1          CS          5008
# 2          CS          5008
# 3          CS          5008
# 4          CS          5008
# ...       ...           ...
# 12657      CS          5004
# 12658      CS          5004
# 12659      CS          5004
# 12660      CS          5004
# 12661      CS          5004
#
#                                                 Question  \
# 0      What were the strengths of this course and/or ...
# 1      What were the strengths of this course and/or ...
# 2      What were the strengths of this course and/or ...
# 3      What were the strengths of this course and/or ...
# 4      What were the strengths of this course and/or ...
# ...                                                  ...
# 12657  What I could have done to make this course bet...
# 12658  What I could have done to make this course bet...
# 12659  What I could have done to make this course bet...
# 12660  What I could have done to make this course bet...
# 12661  What I could have done to make this course bet...
#
#                                                   Review
# 0                       Timing and Canvas are Organized.
# 1                              very responsive professor
# 2      Passionate, knowledgeable, extremely accommoda...
# 3      Scott was a pleasure to have as a professor! I...
# 4      Assignments (homework, labs), and live lecture...
# ...                                                  ...
# 12657  Studied more before class so that I could foll...
# 12658        watch vedios and books ahead may be better.
# 12659  I can utilize the additional resources provide...
# 12660  Spent more time outside of course hours review...
# 12661           do some reading for reference materials.
#
# [12662 rows x 7 columns]

# %%
df.to_csv("./data/reviews.csv", index=False)
