# %%
# !pip install selenium pandas webdriver-manager

# %% [markdown]
# ### Data Scrapping

# %%
import requests
import pandas as pd
import logging
from bs4 import BeautifulSoup
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from functools import partial

# Setup logging to show timestamps
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    datefmt='%H:%M:%S'
)
logger = logging.getLogger(__name__)

# Enhanced day mapping
DAY_MAPPING = {
    'monday': 'Monday',
    'tuesday': 'Tuesday',
    'wednesday': 'Wednesday',
    'thursday': 'Thursday',
    'friday': 'Friday'
}

def get_cookies(base_url):
    """Fetch session cookies."""
    print("\n=== Step 1: Getting Session Cookies ===")
    url = f"{base_url}/term/search"
    headers = {"Content-Type": "application/x-www-form-urlencoded; charset=UTF-8"}
    body = {"term": "202530"}
    
    logger.info("Attempting to get cookies...")
    response = requests.post(url, headers=headers, data=body)
    
    if response.ok:
        logger.info("Successfully got cookies")
        return response.cookies.get_dict()
    else:
        logger.error(f"Failed to get cookies. Status code: {response.status_code}")
        return None

def get_faculty_info(base_url, cookies, crn):
    """Get faculty and meeting time information."""
    logger.info(f"Getting faculty info for course {crn}")
    url = f"{base_url}/searchResults/getFacultyMeetingTimes"
    headers = {"Cookie": "; ".join([f"{key}={value}" for key, value in cookies.items()])}
    params = {"term": "202530", "courseReferenceNumber": crn}
    
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.ok:
            data = response.json().get("fmt", [{}])[0]
            faculty = data.get("faculty", [])
            meeting_time = data.get("meetingTime", {})
            
            # Get full day names
            days = []
            for day, full_name in DAY_MAPPING.items():
                if meeting_time.get(day):
                    days.append(full_name)
            
            return {
                "faculty_name": faculty[0].get("displayName", "") if faculty else "",
                "begin_time": meeting_time.get("beginTime", ""),
                "end_time": meeting_time.get("endTime", ""),
                "days": ", ".join(days)  # Join with commas for readability
            }
    except Exception as e:
        logger.error(f"Error getting faculty info for {crn}: {str(e)}")
        return {"faculty_name": "", "begin_time": "", "end_time": "", "days": ""}

def process_course_batch(base_url, cookies, courses):
    """Process a batch of courses in parallel."""
    results = []
    for course in courses:
        try:
            result = process_course(base_url, cookies, course)
            results.append(result)
        except Exception as e:
            logger.error(f"Error processing course batch: {str(e)}")
    return results

def split_into_batches(data, batch_size=5):
    """Split the data into batches."""
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size]

def get_course_description(base_url, cookies, crn):
    """Get course description."""
    logger.info(f"Getting description for course {crn}")
    url = f"{base_url}/searchResults/getCourseDescription"
    headers = {"Cookie": "; ".join([f"{key}={value}" for key, value in cookies.items()])}
    params = {"term": "202530", "courseReferenceNumber": crn}
    
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.ok:
            soup = BeautifulSoup(response.text, "html.parser")
            description = soup.find("section", {"aria-labelledby": "courseDescription"})
            if description:
                return " ".join(description.get_text().split())
    except Exception as e:
        logger.error(f"Error getting description for {crn}: {str(e)}")
    return ""

def get_prerequisites(base_url, cookies, crn):
    """Get course prerequisites."""
    logger.info(f"Getting prerequisites for course {crn}")
    url = f"{base_url}/searchResults/getSectionPrerequisites"
    headers = {"Cookie": "; ".join([f"{key}={value}" for key, value in cookies.items()])}
    params = {"term": "202530", "courseReferenceNumber": crn}
    
    try:
        response = requests.get(url, headers=headers, params=params)
        if response.ok:
            soup = BeautifulSoup(response.text, "html.parser")
            prereqs = []
            table = soup.find("table", class_="basePreqTable")
            if table and table.find("tbody"):
                for row in table.find("tbody").find_all("tr"):
                    cells = row.find_all("td")
                    prereq = {
                        "and_or": cells[0].text.strip(),
                        "subject": cells[4].text.strip(),
                        "course_number": cells[5].text.strip()
                    }
                    prereqs.append(prereq)
            return str(prereqs)
    except Exception as e:
        logger.error(f"Error getting prerequisites for {crn}: {str(e)}")
    return "[]"

def process_course(base_url, cookies, course):
    """Process a single course."""
    crn = course.get('courseReferenceNumber')
    logger.info(f"\nProcessing course: {crn}")
    
    # Get all course information
    faculty_info = get_faculty_info(base_url, cookies, crn)
    description = get_course_description(base_url, cookies, crn)
    prerequisites = get_prerequisites(base_url, cookies, crn)
    
    # Create course data dictionary
    course_data = {
        'CRN': crn,
        'Campus Description': course.get('campusDescription'),
        'Course Title': course.get('courseTitle'),
        'Subject Course': course.get('subjectCourse'),
        'Faculty Name': faculty_info['faculty_name'],
        'Course Description': description,
        'Term': 'Spring 2025',
        'Begin Time': faculty_info['begin_time'],
        'End Time': faculty_info['end_time'],
        'Days': faculty_info['days'],
        'Prerequisites': prerequisites
    }
    
    logger.info(f"Completed processing course: {crn}")
    return course_data

def get_courses(base_url, cookies):
    """Get course list and process each course using parallel processing."""
    print("\n=== Step 2: Getting Course List ===")
    url = f"{base_url}/searchResults/searchResults"
    headers = {"Cookie": "; ".join([f"{key}={value}" for key, value in cookies.items()])}
    params = {
        "txt_subject": "CS",
        "txt_term": "202530",
        "pageOffset": 0,
        "pageMaxSize": 100000000
    }
    
    logger.info("Fetching course list...")
    response = requests.get(url, headers=headers, params=params)
    
    if response.ok:
        courses = response.json().get('data', [])
        total_courses = len(courses)
        logger.info(f"Found {total_courses} courses to process")
        
        print("\n=== Step 3: Processing Courses in Parallel ===")
        all_course_data = []
        processed_count = 0
        
        # Process courses in parallel batches
        with ThreadPoolExecutor(max_workers=5) as executor:
            batch_processor = partial(process_course_batch, base_url, cookies)
            futures = [
                executor.submit(batch_processor, batch)
                for batch in split_into_batches(courses, batch_size=5)
            ]
            
            for future in as_completed(futures):
                try:
                    batch_results = future.result()
                    all_course_data.extend(batch_results)
                    processed_count += len(batch_results)
                    logger.info(f"Progress: {processed_count}/{total_courses} courses completed ({(processed_count/total_courses)*100:.1f}%)")
                except Exception as e:
                    logger.error(f"Error processing batch: {str(e)}")
        
        return pd.DataFrame(all_course_data)
    else:
        logger.error("Failed to fetch course list")
        return pd.DataFrame()

def main():
    print("\n=== Starting Course Data Collection ===")
    base_url = "https://nubanner.neu.edu/StudentRegistrationSsb/ssb"
    
    # Get cookies
    cookies = get_cookies(base_url)
    if not cookies:
        print("Failed to get cookies. Exiting.")
        return
    
    # Process all courses with parallel processing
    df = get_courses(base_url, cookies)
    
    if not df.empty:
        print("\n=== Step 4: Saving Data ===")
        df.to_csv('./Data/courses.csv', index=False)
        print(f"\nSuccessfully saved data for {len(df)} courses to courses.csv")
        
        # Display sample of the data
        print("\nSample of collected data:")
        print(df[['CRN', 'Course Title', 'Faculty Name', 'Days']].head())
    else:
        print("\nNo course data was collected")
    
    print("\n=== Course Data Collection Complete ===")

if __name__ == "__main__":
    main()
# Out:
# 23:19:11 - Attempting to get cookies...
# 23:19:11 - Successfully got cookies
# 23:19:11 - Fetching course list...
# === Starting Course Data Collection ===
#
# === Step 1: Getting Session Cookies ===
#
# === Step 2: Getting Course List ===
# 23:19:16 - Found 500 courses to process
# 23:19:16 -
# Processing course: 34154
# 23:19:16 -
# Processing course: 30306
# 23:19:16 - Getting faculty info for course 34154
# 23:19:16 -
# Processing course: 32831
# 23:19:16 -
# Processing course: 34157
# 23:19:16 -
# Processing course: 32215
# 23:19:16 - Getting faculty info for course 30306
# 23:19:16 - Getting faculty info for course 32831
# 23:19:16 - Getting faculty info for course 34157
# 23:19:16 - Getting faculty info for course 32215
# 23:19:16 - Getting description for course 34154
# === Step 3: Processing Courses in Parallel ===
# 23:19:16 - Getting description for course 32831
# 23:19:16 - Getting description for course 30306
# 23:19:16 - Getting description for course 34157
# 23:19:16 - Getting description for course 32215
# 23:19:16 - Getting prerequisites for course 34154
# 23:19:16 - Getting prerequisites for course 34157
# 23:19:16 - Getting prerequisites for course 32831
# 23:19:16 - Getting prerequisites for course 30306
# 23:19:16 - Getting prerequisites for course 32215
# 23:19:16 - Completed processing course: 34154
# 23:19:16 -
# Processing course: 32828
# 23:19:16 - Getting faculty info for course 32828
# 23:19:16 - Completed processing course: 30306
# 23:19:16 - Completed processing course: 34157
# 23:19:16 - Completed processing course: 32215
# 23:19:16 - Completed processing course: 32831
# 23:19:16 -
# Processing course: 30305
# 23:19:16 -
# Processing course: 35407
# 23:19:16 - Getting faculty info for course 35407
# 23:19:16 -
# Processing course: 33264
# 23:19:16 - Getting faculty info for course 30305
# 23:19:16 -
# Processing course: 35868
# 23:19:16 - Getting faculty info for course 33264
# 23:19:16 - Getting faculty info for course 35868
# 23:19:17 - Getting description for course 32828
# 23:19:17 - Getting description for course 30305
# 23:19:17 - Getting description for course 35407
# 23:19:17 - Getting description for course 35868
# 23:19:17 - Getting description for course 33264
# 23:19:17 - Getting prerequisites for course 32828
# 23:19:17 - Getting prerequisites for course 30305
# 23:19:17 - Getting prerequisites for course 33264
# 23:19:17 - Getting prerequisites for course 35868
# 23:19:17 - Getting prerequisites for course 35407
# 23:19:17 - Completed processing course: 32828
# 23:19:17 -
# Processing course: 32829
# 23:19:17 - Getting faculty info for course 32829
# 23:19:17 - Completed processing course: 30305
# 23:19:17 -
# Processing course: 31565
# 23:19:17 - Getting faculty info for course 31565
# 23:19:17 - Completed processing course: 35407
# 23:19:17 - Completed processing course: 35868
# 23:19:17 -
# Processing course: 30307
# 23:19:17 -
# Processing course: 37024
# 23:19:17 - Getting faculty info for course 30307
# 23:19:17 - Getting faculty info for course 37024
# 23:19:17 - Completed processing course: 33264
# 23:19:17 -
# Processing course: 33607
# 23:19:17 - Getting faculty info for course 33607
# 23:19:17 - Getting description for course 32829
# 23:19:17 - Getting description for course 31565
# 23:19:17 - Getting description for course 37024
# 23:19:17 - Getting description for course 30307
# 23:19:17 - Getting description for course 33607
# 23:19:17 - Getting prerequisites for course 32829
# 23:19:17 - Getting prerequisites for course 30307
# 23:19:17 - Getting prerequisites for course 37024
# 23:19:17 - Getting prerequisites for course 31565
# 23:19:18 - Getting prerequisites for course 33607
# 23:19:18 - Completed processing course: 37024
# 23:19:18 -
# Processing course: 39788
# 23:19:18 - Getting faculty info for course 39788
# 23:19:18 - Completed processing course: 33607
# 23:19:18 -
# Processing course: 33608
# 23:19:18 - Getting faculty info for course 33608
# 23:19:18 - Completed processing course: 32829
# 23:19:18 -
# Processing course: 32830
# 23:19:18 - Getting faculty info for course 32830
# 23:19:18 - Completed processing course: 30307
# 23:19:18 -
# Processing course: 34586
# 23:19:18 - Getting faculty info for course 34586
# 23:19:18 - Completed processing course: 31565
# 23:19:18 -
# Processing course: 31721
# 23:19:18 - Getting faculty info for course 31721
# 23:19:18 - Getting description for course 39788
# 23:19:18 - Getting description for course 32830
# 23:19:18 - Getting description for course 33608
# 23:19:18 - Getting description for course 31721
# 23:19:18 - Getting description for course 34586
# 23:19:18 - Getting prerequisites for course 32830
# 23:19:18 - Getting prerequisites for course 39788
# 23:19:18 - Getting prerequisites for course 33608
# 23:19:18 - Getting prerequisites for course 31721
# 23:19:18 - Getting prerequisites for course 34586
# 23:19:18 - Completed processing course: 32830
# 23:19:18 -
# Processing course: 34155
# 23:19:18 - Getting faculty info for course 34155
# 23:19:18 - Completed processing course: 39788
# 23:19:18 -
# Processing course: 40824
# 23:19:18 - Getting faculty info for course 40824
# 23:19:18 - Completed processing course: 34586
# 23:19:18 -
# Processing course: 40823
# 23:19:18 - Getting faculty info for course 40823
# 23:19:18 - Completed processing course: 31721
# 23:19:18 -
# Processing course: 32214
# 23:19:18 - Getting faculty info for course 32214
# 23:19:18 - Completed processing course: 33608
# 23:19:18 -
# Processing course: 34156
# 23:19:18 - Getting faculty info for course 34156
# 23:19:18 - Getting description for course 34155
# 23:19:18 - Getting description for course 40823
# 23:19:18 - Getting description for course 40824
# 23:19:18 - Getting description for course 32214
# 23:19:19 - Getting description for course 34156
# 23:19:19 - Getting prerequisites for course 34155
# 23:19:19 - Getting prerequisites for course 40823
# 23:19:19 - Getting prerequisites for course 40824
# 23:19:19 - Getting prerequisites for course 32214
# 23:19:19 - Getting prerequisites for course 34156
# 23:19:19 - Completed processing course: 34155
# 23:19:19 -
# Processing course: 34158
# 23:19:19 - Progress: 5/500 courses completed (1.0%)
# 23:19:19 - Getting faculty info for course 34158
# 23:19:19 - Completed processing course: 40823
# 23:19:19 -
# Processing course: 34159
# 23:19:19 - Progress: 10/500 courses completed (2.0%)
# 23:19:19 - Getting faculty info for course 34159
# 23:19:19 - Completed processing course: 40824
# 23:19:19 -
# Processing course: 34161
# 23:19:19 - Progress: 15/500 courses completed (3.0%)
# 23:19:19 - Getting faculty info for course 34161
# 23:19:19 - Completed processing course: 32214
# 23:19:19 -
# Processing course: 34162
# 23:19:19 - Progress: 20/500 courses completed (4.0%)
# 23:19:19 - Getting faculty info for course 34162
# 23:19:19 - Completed processing course: 34156
# 23:19:19 -
# Processing course: 37168
# 23:19:19 - Progress: 25/500 courses completed (5.0%)
# 23:19:19 - Getting faculty info for course 37168
# 23:19:19 - Getting description for course 34159
# 23:19:19 - Getting description for course 34161
# 23:19:19 - Getting description for course 34158
# 23:19:19 - Getting description for course 34162
# 23:19:19 - Getting description for course 37168
# 23:19:19 - Getting prerequisites for course 34159
# 23:19:19 - Getting prerequisites for course 34158
# 23:19:19 - Getting prerequisites for course 34161
# 23:19:19 - Getting prerequisites for course 34162
# 23:19:19 - Getting prerequisites for course 37168
# 23:19:19 - Completed processing course: 34159
# 23:19:19 - Completed processing course: 34161
# 23:19:19 -
# Processing course: 34160
# 23:19:19 -
# Processing course: 39790
# 23:19:19 - Getting faculty info for course 34160
# 23:19:19 - Getting faculty info for course 39790
# 23:19:19 - Completed processing course: 34158
# 23:19:19 -
# Processing course: 31296
# 23:19:19 - Getting faculty info for course 31296
# 23:19:20 - Completed processing course: 34162
# 23:19:20 -
# Processing course: 31975
# 23:19:20 - Getting faculty info for course 31975
# 23:19:20 - Completed processing course: 37168
# 23:19:20 -
# Processing course: 34165
# 23:19:20 - Getting faculty info for course 34165
# 23:19:20 - Getting description for course 39790
# 23:19:20 - Getting description for course 34160
# 23:19:20 - Getting description for course 31296
# 23:19:20 - Getting description for course 31975
# 23:19:20 - Getting description for course 34165
# 23:19:20 - Getting prerequisites for course 39790
# 23:19:20 - Getting prerequisites for course 31296
# 23:19:20 - Getting prerequisites for course 34160
# 23:19:20 - Getting prerequisites for course 31975
# 23:19:20 - Getting prerequisites for course 34165
# 23:19:20 - Completed processing course: 34160
# 23:19:20 - Completed processing course: 39790
# 23:19:20 - Completed processing course: 31296
# 23:19:20 -
# Processing course: 32105
# 23:19:20 -
# Processing course: 30194
# 23:19:20 -
# Processing course: 39789
# 23:19:20 - Getting faculty info for course 32105
# 23:19:20 - Getting faculty info for course 30194
# 23:19:20 - Getting faculty info for course 39789
# 23:19:20 - Completed processing course: 31975
# 23:19:20 -
# Processing course: 37169
# 23:19:20 - Getting faculty info for course 37169
# 23:19:20 - Completed processing course: 34165
# 23:19:20 -
# Processing course: 30188
# 23:19:20 - Getting faculty info for course 30188
# 23:19:20 - Getting description for course 30194
# 23:19:20 - Getting description for course 39789
# 23:19:20 - Getting description for course 32105
# 23:19:20 - Getting description for course 37169
# 23:19:20 - Getting description for course 30188
# 23:19:21 - Getting prerequisites for course 30194
# 23:19:21 - Getting prerequisites for course 39789
# 23:19:21 - Getting prerequisites for course 32105
# 23:19:21 - Getting prerequisites for course 37169
# 23:19:21 - Getting prerequisites for course 30188
# 23:19:21 - Completed processing course: 30194
# 23:19:21 -
# Processing course: 30193
# 23:19:21 - Getting faculty info for course 30193
# 23:19:21 - Completed processing course: 39789
# 23:19:21 -
# Processing course: 30215
# 23:19:21 - Getting faculty info for course 30215
# 23:19:21 - Completed processing course: 32105
# 23:19:21 -
# Processing course: 32106
# 23:19:21 - Getting faculty info for course 32106
# 23:19:21 - Completed processing course: 30188
# 23:19:21 - Completed processing course: 37169
# 23:19:21 -
# Processing course: 34166
# 23:19:21 -
# Processing course: 37121
# 23:19:21 - Getting faculty info for course 34166
# 23:19:21 - Getting faculty info for course 37121
# 23:19:21 - Getting description for course 30193
# 23:19:21 - Getting description for course 30215
# 23:19:21 - Getting description for course 32106
# 23:19:21 - Getting description for course 37121
# 23:19:21 - Getting description for course 34166
# 23:19:21 - Getting prerequisites for course 30193
# 23:19:21 - Getting prerequisites for course 30215
# 23:19:21 - Getting prerequisites for course 32106
# 23:19:21 - Getting prerequisites for course 37121
# 23:19:21 - Getting prerequisites for course 34166
# 23:19:21 - Completed processing course: 30193
# 23:19:21 -
# Processing course: 31825
# 23:19:21 - Getting faculty info for course 31825
# 23:19:21 - Completed processing course: 30215
# 23:19:21 - Completed processing course: 32106
# 23:19:21 -
# Processing course: 31220
# 23:19:21 -
# Processing course: 32832
# 23:19:21 - Getting faculty info for course 31220
# 23:19:21 - Getting faculty info for course 32832
# 23:19:21 - Completed processing course: 37121
# 23:19:21 -
# Processing course: 37167
# 23:19:21 - Getting faculty info for course 37167
# 23:19:21 - Completed processing course: 34166
# 23:19:21 -
# Processing course: 30989
# 23:19:21 - Getting faculty info for course 30989
# 23:19:22 - Getting description for course 31220
# 23:19:22 - Getting description for course 32832
# 23:19:22 - Getting description for course 31825
# 23:19:22 - Getting description for course 37167
# 23:19:22 - Getting description for course 30989
# 23:19:22 - Getting prerequisites for course 31825
# 23:19:22 - Getting prerequisites for course 32832
# 23:19:22 - Getting prerequisites for course 31220
# 23:19:22 - Getting prerequisites for course 37167
# 23:19:22 - Getting prerequisites for course 30989
# 23:19:22 - Completed processing course: 32832
# 23:19:22 - Completed processing course: 31220
# 23:19:22 -
# Processing course: 31566
# 23:19:22 - Progress: 30/500 courses completed (6.0%)
# 23:19:22 -
# Processing course: 34167
# 23:19:22 - Getting faculty info for course 31566
# 23:19:22 - Progress: 35/500 courses completed (7.0%)
# 23:19:22 - Getting faculty info for course 34167
# 23:19:22 - Completed processing course: 31825
# 23:19:22 -
# Processing course: 34172
# 23:19:22 - Progress: 40/500 courses completed (8.0%)
# 23:19:22 - Getting faculty info for course 34172
# 23:19:22 - Completed processing course: 37167
# 23:19:22 -
# Processing course: 37179
# 23:19:22 - Progress: 45/500 courses completed (9.0%)
# 23:19:22 - Getting faculty info for course 37179
# 23:19:22 - Completed processing course: 30989
# 23:19:22 -
# Processing course: 32496
# 23:19:22 - Progress: 50/500 courses completed (10.0%)
# 23:19:22 - Getting faculty info for course 32496
# 23:19:22 - Getting description for course 31566
# 23:19:22 - Getting description for course 34167
# 23:19:22 - Getting description for course 34172
# 23:19:22 - Getting description for course 37179
# 23:19:22 - Getting description for course 32496
# 23:19:22 - Getting prerequisites for course 34167
# 23:19:22 - Getting prerequisites for course 31566
# 23:19:22 - Getting prerequisites for course 34172
# 23:19:22 - Getting prerequisites for course 37179
# 23:19:23 - Getting prerequisites for course 32496
# 23:19:23 - Completed processing course: 34167
# 23:19:23 -
# Processing course: 34168
# 23:19:23 - Getting faculty info for course 34168
# 23:19:23 - Completed processing course: 31566
# 23:19:23 - Completed processing course: 34172
# 23:19:23 -
# Processing course: 31567
# 23:19:23 -
# Processing course: 37175
# 23:19:23 - Getting faculty info for course 31567
# 23:19:23 - Getting faculty info for course 37175
# 23:19:23 - Completed processing course: 37179
# 23:19:23 -
# Processing course: 37180
# 23:19:23 - Getting faculty info for course 37180
# 23:19:23 - Completed processing course: 32496
# 23:19:23 -
# Processing course: 34176
# 23:19:23 - Getting faculty info for course 34176
# 23:19:23 - Getting description for course 34168
# 23:19:23 - Getting description for course 31567
# 23:19:23 - Getting description for course 37175
# 23:19:23 - Getting description for course 37180
# 23:19:23 - Getting description for course 34176
# 23:19:23 - Getting prerequisites for course 34168
# 23:19:23 - Getting prerequisites for course 37175
# 23:19:23 - Getting prerequisites for course 31567
# 23:19:23 - Getting prerequisites for course 37180
# 23:19:23 - Getting prerequisites for course 34176
# 23:19:23 - Completed processing course: 34168
# 23:19:23 -
# Processing course: 33265
# 23:19:23 - Getting faculty info for course 33265
# 23:19:23 - Completed processing course: 37175
# 23:19:23 - Completed processing course: 31567
# 23:19:23 -
# Processing course: 37176
# 23:19:23 -
# Processing course: 31976
# 23:19:23 - Getting faculty info for course 37176
# 23:19:23 - Getting faculty info for course 31976
# 23:19:23 - Completed processing course: 37180
# 23:19:23 -
# Processing course: 35411
# 23:19:23 - Getting faculty info for course 35411
# 23:19:24 - Completed processing course: 34176
# 23:19:24 -
# Processing course: 41607
# 23:19:24 - Getting faculty info for course 41607
# 23:19:24 - Getting description for course 33265
# 23:19:24 - Getting description for course 37176
# 23:19:24 - Getting description for course 31976
# 23:19:24 - Getting description for course 35411
# 23:19:24 - Getting description for course 41607
# 23:19:24 - Getting prerequisites for course 33265
# 23:19:24 - Getting prerequisites for course 37176
# 23:19:24 - Getting prerequisites for course 31976
# 23:19:24 - Getting prerequisites for course 35411
# 23:19:24 - Getting prerequisites for course 41607
# 23:19:24 - Completed processing course: 33265
# 23:19:24 -
# Processing course: 34169
# 23:19:24 - Getting faculty info for course 34169
# 23:19:24 - Completed processing course: 37176
# 23:19:24 -
# Processing course: 37177
# 23:19:24 - Getting faculty info for course 37177
# 23:19:24 - Completed processing course: 31976
# 23:19:24 -
# Processing course: 31977
# 23:19:24 - Getting faculty info for course 31977
# 23:19:24 - Completed processing course: 35411
# 23:19:24 -
# Processing course: 39791
# 23:19:24 - Getting faculty info for course 39791
# 23:19:24 - Completed processing course: 41607
# 23:19:24 -
# Processing course: 33266
# 23:19:24 - Getting faculty info for course 33266
# 23:19:24 - Getting description for course 34169
# 23:19:24 - Getting description for course 31977
# 23:19:24 - Getting description for course 37177
# 23:19:24 - Getting description for course 39791
# 23:19:24 - Getting description for course 33266
# 23:19:25 - Getting prerequisites for course 34169
# 23:19:25 - Getting prerequisites for course 37177
# 23:19:25 - Getting prerequisites for course 31977
# 23:19:25 - Getting prerequisites for course 39791
# 23:19:25 - Getting prerequisites for course 33266
# 23:19:25 - Completed processing course: 37177
# 23:19:25 - Completed processing course: 34169
# 23:19:25 -
# Processing course: 37178
# 23:19:25 -
# Processing course: 34171
# 23:19:25 - Getting faculty info for course 37178
# 23:19:25 - Getting faculty info for course 34171
# 23:19:25 - Completed processing course: 31977
# 23:19:25 -
# Processing course: 32217
# 23:19:25 - Getting faculty info for course 32217
# 23:19:25 - Completed processing course: 39791
# 23:19:25 -
# Processing course: 39792
# 23:19:25 - Getting faculty info for course 39792
# 23:19:25 - Completed processing course: 33266
# 23:19:25 -
# Processing course: 33267
# 23:19:25 - Getting faculty info for course 33267
# 23:19:25 - Getting description for course 37178
# 23:19:25 - Getting description for course 34171
# 23:19:25 - Getting description for course 32217
# 23:19:25 - Getting description for course 39792
# 23:19:25 - Getting description for course 33267
# 23:19:25 - Getting prerequisites for course 34171
# 23:19:25 - Getting prerequisites for course 37178
# 23:19:25 - Getting prerequisites for course 32217
# 23:19:25 - Getting prerequisites for course 39792
# 23:19:25 - Getting prerequisites for course 33267
# 23:19:25 - Completed processing course: 34171
# 23:19:25 -
# Processing course: 33268
# 23:19:25 - Progress: 55/500 courses completed (11.0%)
# 23:19:25 - Getting faculty info for course 33268
# 23:19:25 - Completed processing course: 37178
# 23:19:25 -
# Processing course: 35414
# 23:19:25 - Progress: 60/500 courses completed (12.0%)
# 23:19:25 - Getting faculty info for course 35414
# 23:19:25 - Completed processing course: 32217
# 23:19:25 -
# Processing course: 37174
# 23:19:25 - Progress: 65/500 courses completed (13.0%)
# 23:19:25 - Getting faculty info for course 37174
# 23:19:26 - Completed processing course: 39792
# 23:19:26 -
# Processing course: 31724
# 23:19:26 - Progress: 70/500 courses completed (14.0%)
# 23:19:26 - Getting faculty info for course 31724
# 23:19:26 - Completed processing course: 33267
# 23:19:26 -
# Processing course: 34181
# 23:19:26 - Progress: 75/500 courses completed (15.0%)
# 23:19:26 - Getting faculty info for course 34181
# 23:19:26 - Getting description for course 33268
# 23:19:26 - Getting description for course 35414
# 23:19:26 - Getting description for course 37174
# 23:19:26 - Getting description for course 31724
# 23:19:26 - Getting description for course 34181
# 23:19:26 - Getting prerequisites for course 33268
# 23:19:26 - Getting prerequisites for course 35414
# 23:19:26 - Getting prerequisites for course 37174
# 23:19:26 - Getting prerequisites for course 31724
# 23:19:26 - Getting prerequisites for course 34181
# 23:19:26 - Completed processing course: 35414
# 23:19:26 - Completed processing course: 33268
# 23:19:26 -
# Processing course: 41608
# 23:19:26 -
# Processing course: 33269
# 23:19:26 - Getting faculty info for course 41608
# 23:19:26 - Getting faculty info for course 33269
# 23:19:26 - Completed processing course: 37174
# 23:19:26 -
# Processing course: 39793
# 23:19:26 - Getting faculty info for course 39793
# 23:19:26 - Completed processing course: 31724
# 23:19:26 -
# Processing course: 34177
# 23:19:26 - Getting faculty info for course 34177
# 23:19:26 - Completed processing course: 34181
# 23:19:26 -
# Processing course: 37027
# 23:19:26 - Getting faculty info for course 37027
# 23:19:26 - Getting description for course 33269
# 23:19:26 - Getting description for course 41608
# 23:19:26 - Getting description for course 39793
# 23:19:26 - Getting description for course 34177
# 23:19:26 - Getting description for course 37027
# 23:19:26 - Getting prerequisites for course 41608
# 23:19:26 - Getting prerequisites for course 33269
# 23:19:26 - Getting prerequisites for course 39793
# 23:19:26 - Getting prerequisites for course 34177
# 23:19:27 - Getting prerequisites for course 37027
# 23:19:27 - Completed processing course: 41608
# 23:19:27 -
# Processing course: 30292
# 23:19:27 - Getting faculty info for course 30292
# 23:19:27 - Completed processing course: 33269
# 23:19:27 -
# Processing course: 33270
# 23:19:27 - Getting faculty info for course 33270
# 23:19:27 - Completed processing course: 39793
# 23:19:27 -
# Processing course: 40194
# 23:19:27 - Getting faculty info for course 40194
# 23:19:27 - Completed processing course: 34177
# 23:19:27 -
# Processing course: 34178
# 23:19:27 - Getting faculty info for course 34178
# 23:19:27 - Getting description for course 33270
# 23:19:27 - Getting prerequisites for course 33270
# 23:19:31 - Completed processing course: 37027
# 23:19:31 -
# Processing course: 31979
# 23:19:31 - Getting faculty info for course 31979
# 23:19:31 - Getting description for course 30292
# 23:19:31 - Getting description for course 40194
# 23:19:31 - Getting description for course 34178
# 23:19:31 - Getting prerequisites for course 40194
# 23:19:31 - Getting prerequisites for course 34178
# 23:19:31 - Completed processing course: 33270
# 23:19:31 -
# Processing course: 33271
# 23:19:31 - Getting faculty info for course 33271
# 23:19:31 - Getting description for course 33271
# 23:19:32 - Getting prerequisites for course 33271
# 23:19:32 - Completed processing course: 33271
# 23:19:32 -
# Processing course: 35413
# 23:19:32 - Getting faculty info for course 35413
# 23:19:32 - Getting description for course 31979
# 23:19:32 - Getting description for course 35413
# 23:19:32 - Getting prerequisites for course 30292
# 23:19:32 - Getting prerequisites for course 31979
# 23:19:32 - Getting prerequisites for course 35413
# 23:19:32 - Completed processing course: 30292
# 23:19:32 -
# Processing course: 31978
# 23:19:32 - Getting faculty info for course 31978
# 23:19:32 - Completed processing course: 34178
# 23:19:32 -
# Processing course: 34179
# 23:19:32 - Getting faculty info for course 34179
# 23:19:32 - Completed processing course: 40194
# 23:19:32 -
# Processing course: 41222
# 23:19:32 - Getting faculty info for course 41222
# 23:19:32 - Completed processing course: 31979
# 23:19:32 -
# Processing course: 31297
# 23:19:32 - Getting faculty info for course 31297
# 23:19:32 - Completed processing course: 35413
# 23:19:32 -
# Processing course: 32218
# 23:19:32 - Progress: 80/500 courses completed (16.0%)
# 23:19:32 - Getting faculty info for course 32218
# 23:19:32 - Getting description for course 34179
# 23:19:32 - Getting description for course 31978
# 23:19:32 - Getting description for course 41222
# 23:19:33 - Getting description for course 31297
# 23:19:33 - Getting description for course 32218
# 23:19:33 - Getting prerequisites for course 34179
# 23:19:33 - Getting prerequisites for course 31978
# 23:19:33 - Getting prerequisites for course 41222
# 23:19:33 - Getting prerequisites for course 31297
# 23:19:33 - Completed processing course: 34179
# 23:19:33 -
# Processing course: 34180
# 23:19:33 - Getting faculty info for course 34180
# 23:19:33 - Getting prerequisites for course 32218
# 23:19:33 - Completed processing course: 31978
# 23:19:33 -
# Processing course: 37173
# 23:19:33 - Getting faculty info for course 37173
# 23:19:33 - Completed processing course: 41222
# 23:19:33 -
# Processing course: 30304
# 23:19:33 - Getting faculty info for course 30304
# 23:19:33 - Completed processing course: 31297
# 23:19:33 -
# Processing course: 37028
# 23:19:33 - Getting faculty info for course 37028
# 23:19:33 - Getting description for course 37173
# 23:19:33 - Getting description for course 34180
# 23:19:33 - Completed processing course: 32218
# 23:19:33 - Getting description for course 30304
# 23:19:33 -
# Processing course: 32219
# 23:19:33 - Getting faculty info for course 32219
# 23:19:33 - Getting description for course 37028
# 23:19:33 - Getting prerequisites for course 37173
# 23:19:33 - Getting prerequisites for course 34180
# 23:19:33 - Getting description for course 32219
# 23:19:33 - Getting prerequisites for course 30304
# 23:19:33 - Getting prerequisites for course 37028
# 23:19:33 - Completed processing course: 34180
# 23:19:33 -
# Processing course: 39795
# 23:19:33 - Progress: 85/500 courses completed (17.0%)
# 23:19:33 - Getting faculty info for course 39795
# 23:19:33 - Completed processing course: 37173
# 23:19:33 -
# Processing course: 39797
# 23:19:33 - Progress: 90/500 courses completed (18.0%)
# 23:19:33 - Getting faculty info for course 39797
# 23:19:33 - Getting prerequisites for course 32219
# 23:19:34 - Completed processing course: 30304
# 23:19:34 -
# Processing course: 30291
# 23:19:34 - Progress: 95/500 courses completed (19.0%)
# 23:19:34 - Getting faculty info for course 30291
# 23:19:34 - Completed processing course: 37028
# 23:19:34 -
# Processing course: 34183
# 23:19:34 - Progress: 100/500 courses completed (20.0%)
# 23:19:34 - Getting faculty info for course 34183
# 23:19:34 - Getting description for course 39795
# 23:19:34 - Getting description for course 39797
# 23:19:34 - Completed processing course: 32219
# 23:19:34 -
# Processing course: 32834
# 23:19:34 - Getting faculty info for course 32834
# 23:19:34 - Getting description for course 30291
# 23:19:34 - Getting description for course 34183
# 23:19:34 - Getting prerequisites for course 39797
# 23:19:34 - Getting prerequisites for course 39795
# 23:19:34 - Getting description for course 32834
# 23:19:34 - Getting prerequisites for course 30291
# 23:19:34 - Getting prerequisites for course 34183
# 23:19:34 - Completed processing course: 39797
# 23:19:34 -
# Processing course: 35416
# 23:19:34 - Getting faculty info for course 35416
# 23:19:34 - Completed processing course: 39795
# 23:19:34 - Getting prerequisites for course 32834
# 23:19:34 - Completed processing course: 30291
# 23:19:34 -
# Processing course: 40109
# 23:19:34 -
# Processing course: 37030
# 23:19:34 - Getting faculty info for course 40109
# 23:19:34 - Getting faculty info for course 37030
# 23:19:34 - Completed processing course: 34183
# 23:19:34 -
# Processing course: 34184
# 23:19:34 - Getting faculty info for course 34184
# 23:19:34 - Getting description for course 35416
# 23:19:34 - Getting description for course 37030
# 23:19:34 - Getting description for course 40109
# 23:19:34 - Completed processing course: 32834
# 23:19:34 -
# Processing course: 39794
# 23:19:34 - Getting faculty info for course 39794
# 23:19:34 - Getting description for course 34184
# 23:19:34 - Getting prerequisites for course 35416
# 23:19:35 - Getting description for course 39794
# 23:19:35 - Getting prerequisites for course 37030
# 23:19:35 - Getting prerequisites for course 40109
# 23:19:35 - Getting prerequisites for course 34184
# 23:19:35 - Completed processing course: 35416
# 23:19:35 -
# Processing course: 40232
# 23:19:35 - Getting faculty info for course 40232
# 23:19:35 - Completed processing course: 37030
# 23:19:35 - Getting prerequisites for course 39794
# 23:19:35 - Completed processing course: 40109
# 23:19:35 -
# Processing course: 31723
# 23:19:35 -
# Processing course: 32497
# 23:19:35 - Getting faculty info for course 31723
# 23:19:35 - Getting faculty info for course 32497
# 23:19:35 - Completed processing course: 34184
# 23:19:35 -
# Processing course: 37239
# 23:19:35 - Getting faculty info for course 37239
# 23:19:35 - Getting description for course 40232
# 23:19:35 - Getting description for course 31723
# 23:19:35 - Completed processing course: 39794
# 23:19:35 -
# Processing course: 30303
# 23:19:35 - Getting faculty info for course 30303
# 23:19:35 - Getting description for course 37239
# 23:19:35 - Getting prerequisites for course 40232
# 23:19:35 - Getting prerequisites for course 31723
# 23:19:35 - Getting description for course 30303
# 23:19:35 - Getting prerequisites for course 37239
# 23:19:35 - Completed processing course: 40232
# 23:19:35 -
# Processing course: 37029
# 23:19:35 - Getting faculty info for course 37029
# 23:19:35 - Completed processing course: 31723
# 23:19:35 -
# Processing course: 37101
# 23:19:35 - Getting faculty info for course 37101
# 23:19:35 - Getting prerequisites for course 30303
# 23:19:35 - Completed processing course: 37239
# 23:19:35 -
# Processing course: 41345
# 23:19:35 - Getting faculty info for course 41345
# 23:19:36 - Getting description for course 37029
# 23:19:36 - Completed processing course: 30303
# 23:19:36 -
# Processing course: 35470
# 23:19:36 - Progress: 105/500 courses completed (21.0%)
# 23:19:36 - Getting faculty info for course 35470
# 23:19:36 - Getting description for course 37101
# 23:19:36 - Getting description for course 41345
# 23:19:36 - Getting prerequisites for course 37029
# 23:19:36 - Getting description for course 35470
# 23:19:36 - Getting prerequisites for course 37101
# 23:19:36 - Getting prerequisites for course 41345
# 23:19:36 - Getting description for course 32497
# 23:19:36 - Completed processing course: 37029
# 23:19:36 -
# Processing course: 38532
# 23:19:36 - Getting faculty info for course 38532
# 23:19:36 - Completed processing course: 37101
# 23:19:36 -
# Processing course: 33272
# 23:19:36 - Getting faculty info for course 33272
# 23:19:36 - Completed processing course: 41345
# 23:19:36 -
# Processing course: 37031
# 23:19:36 - Getting faculty info for course 37031
# 23:19:36 - Getting description for course 38532
# 23:19:36 - Getting prerequisites for course 32497
# 23:19:36 - Getting description for course 33272
# 23:19:36 - Getting description for course 37031
# 23:19:36 - Getting prerequisites for course 38532
# 23:19:36 - Completed processing course: 32497
# 23:19:36 -
# Processing course: 39796
# 23:19:36 - Getting faculty info for course 39796
# 23:19:36 - Getting prerequisites for course 33272
# 23:19:36 - Getting prerequisites for course 37031
# 23:19:37 - Getting description for course 39796
# 23:19:37 - Completed processing course: 38532
# 23:19:37 -
# Processing course: 35471
# 23:19:37 - Progress: 110/500 courses completed (22.0%)
# 23:19:37 - Getting faculty info for course 35471
# 23:19:37 - Completed processing course: 33272
# 23:19:37 -
# Processing course: 39805
# 23:19:37 - Progress: 115/500 courses completed (23.0%)
# 23:19:37 - Getting faculty info for course 39805
# 23:19:37 - Completed processing course: 37031
# 23:19:37 -
# Processing course: 40551
# 23:19:37 - Progress: 120/500 courses completed (24.0%)
# 23:19:37 - Getting faculty info for course 40551
# 23:19:37 - Getting prerequisites for course 39796
# 23:19:37 - Getting description for course 35471
# 23:19:37 - Getting description for course 40551
# 23:19:37 - Getting prerequisites for course 35470
# 23:19:37 - Getting prerequisites for course 35471
# 23:19:37 - Getting prerequisites for course 40551
# 23:19:37 - Completed processing course: 35470
# 23:19:37 -
# Processing course: 32498
# 23:19:37 - Getting faculty info for course 32498
# 23:19:37 - Completed processing course: 35471
# 23:19:37 -
# Processing course: 37240
# 23:19:37 - Getting faculty info for course 37240
# 23:19:37 - Completed processing course: 40551
# 23:19:37 -
# Processing course: 40614
# 23:19:37 - Getting faculty info for course 40614
# 23:19:37 - Getting description for course 32498
# 23:19:37 - Getting description for course 37240
# 23:19:38 - Getting description for course 40614
# 23:19:38 - Getting prerequisites for course 32498
# 23:19:38 - Getting prerequisites for course 37240
# 23:19:38 - Getting prerequisites for course 40614
# 23:19:38 - Completed processing course: 37240
# 23:19:38 -
# Processing course: 37246
# 23:19:38 - Getting faculty info for course 37246
# 23:19:38 - Completed processing course: 32498
# 23:19:38 -
# Processing course: 39800
# 23:19:38 - Getting faculty info for course 39800
# 23:19:38 - Getting description for course 39805
# 23:19:38 - Completed processing course: 40614
# 23:19:38 -
# Processing course: 41834
# 23:19:38 - Getting faculty info for course 41834
# 23:19:38 - Completed processing course: 39796
# 23:19:38 -
# Processing course: 30174
# 23:19:38 - Getting faculty info for course 30174
# 23:19:38 - Getting description for course 37246
# 23:19:38 - Getting description for course 39800
# 23:19:38 - Getting description for course 41834
# 23:19:38 - Getting prerequisites for course 39805
# 23:19:38 - Getting description for course 30174
# 23:19:38 - Getting prerequisites for course 37246
# 23:19:38 - Getting prerequisites for course 39800
# 23:19:38 - Getting prerequisites for course 41834
# 23:19:38 - Completed processing course: 39805
# 23:19:38 -
# Processing course: 39806
# 23:19:38 - Getting faculty info for course 39806
# 23:19:38 - Getting prerequisites for course 30174
# 23:19:38 - Completed processing course: 37246
# 23:19:38 -
# Processing course: 38144
# 23:19:38 - Getting faculty info for course 38144
# 23:19:38 - Completed processing course: 39800
# 23:19:38 -
# Processing course: 39801
# 23:19:38 - Getting faculty info for course 39801
# 23:19:38 - Completed processing course: 41834
# 23:19:38 -
# Processing course: 40682
# 23:19:38 - Getting faculty info for course 40682
# 23:19:39 - Getting description for course 39806
# 23:19:39 - Completed processing course: 30174
# 23:19:39 -
# Processing course: 35417
# 23:19:39 - Progress: 125/500 courses completed (25.0%)
# 23:19:39 - Getting faculty info for course 35417
# 23:19:39 - Getting description for course 38144
# 23:19:39 - Getting description for course 39801
# 23:19:39 - Getting description for course 40682
# 23:19:39 - Getting prerequisites for course 39806
# 23:19:39 - Getting description for course 35417
# 23:19:39 - Getting prerequisites for course 38144
# 23:19:39 - Getting prerequisites for course 39801
# 23:19:39 - Getting prerequisites for course 40682
# 23:19:39 - Completed processing course: 39806
# 23:19:39 -
# Processing course: 41142
# 23:19:39 - Getting faculty info for course 41142
# 23:19:39 - Getting prerequisites for course 35417
# 23:19:39 - Completed processing course: 38144
# 23:19:39 -
# Processing course: 39804
# 23:19:39 - Getting faculty info for course 39804
# 23:19:39 - Completed processing course: 40682
# 23:19:39 -
# Processing course: 40683
# 23:19:39 - Getting faculty info for course 40683
# 23:19:39 - Completed processing course: 39801
# 23:19:39 -
# Processing course: 39802
# 23:19:39 - Getting faculty info for course 39802
# 23:19:39 - Getting description for course 41142
# 23:19:39 - Getting description for course 39804
# 23:19:39 - Completed processing course: 35417
# 23:19:39 -
# Processing course: 35638
# 23:19:39 - Getting faculty info for course 35638
# 23:19:39 - Getting description for course 40683
# 23:19:39 - Getting description for course 39802
# 23:19:39 - Getting prerequisites for course 41142
# 23:19:39 - Getting prerequisites for course 39804
# 23:19:39 - Getting description for course 35638
# 23:19:39 - Getting prerequisites for course 40683
# 23:19:39 - Getting prerequisites for course 39802
# 23:19:40 - Completed processing course: 41142
# 23:19:40 -
# Processing course: 41678
# 23:19:40 - Getting faculty info for course 41678
# 23:19:40 - Completed processing course: 39804
# 23:19:40 -
# Processing course: 40687
# 23:19:40 - Progress: 130/500 courses completed (26.0%)
# 23:19:40 - Getting faculty info for course 40687
# 23:19:40 - Getting prerequisites for course 35638
# 23:19:40 - Completed processing course: 40683
# 23:19:40 -
# Processing course: 40688
# 23:19:40 - Progress: 135/500 courses completed (27.0%)
# 23:19:40 - Getting faculty info for course 40688
# 23:19:40 - Completed processing course: 39802
# 23:19:40 -
# Processing course: 40554
# 23:19:40 - Progress: 140/500 courses completed (28.0%)
# 23:19:40 - Getting faculty info for course 40554
# 23:19:40 - Getting description for course 41678
# 23:19:40 - Getting description for course 40687
# 23:19:40 - Completed processing course: 35638
# 23:19:40 -
# Processing course: 40552
# 23:19:40 - Getting faculty info for course 40552
# 23:19:40 - Getting description for course 40688
# 23:19:40 - Getting description for course 40554
# 23:19:40 - Getting prerequisites for course 41678
# 23:19:40 - Getting description for course 40552
# 23:19:40 - Getting prerequisites for course 40687
# 23:19:40 - Getting prerequisites for course 40688
# 23:19:40 - Getting prerequisites for course 40554
# 23:19:40 - Completed processing course: 41678
# 23:19:40 -
# Processing course: 32083
# 23:19:40 - Getting faculty info for course 32083
# 23:19:40 - Getting prerequisites for course 40552
# 23:19:40 - Completed processing course: 40687
# 23:19:40 -
# Processing course: 32084
# 23:19:40 - Getting faculty info for course 32084
# 23:19:40 - Completed processing course: 40554
# 23:19:40 -
# Processing course: 40620
# 23:19:40 - Getting faculty info for course 40620
# 23:19:40 - Completed processing course: 40688
# 23:19:40 -
# Processing course: 40689
# 23:19:40 - Getting faculty info for course 40689
# 23:19:40 - Getting description for course 32083
# 23:19:40 - Completed processing course: 40552
# 23:19:40 -
# Processing course: 40617
# 23:19:40 - Getting faculty info for course 40617
# 23:19:40 - Getting description for course 32084
# 23:19:40 - Getting description for course 40620
# 23:19:40 - Getting description for course 40689
# 23:19:41 - Getting prerequisites for course 32083
# 23:19:41 - Getting description for course 40617
# 23:19:41 - Getting prerequisites for course 32084
# 23:19:41 - Getting prerequisites for course 40620
# 23:19:41 - Getting prerequisites for course 40689
# 23:19:41 - Completed processing course: 32083
# 23:19:41 -
# Processing course: 40694
# 23:19:41 - Progress: 145/500 courses completed (29.0%)
# 23:19:41 - Getting faculty info for course 40694
# 23:19:41 - Getting prerequisites for course 40617
# 23:19:41 - Completed processing course: 32084
# 23:19:41 -
# Processing course: 35641
# 23:19:41 - Getting faculty info for course 35641
# 23:19:41 - Completed processing course: 40689
# 23:19:41 -
# Processing course: 40690
# 23:19:41 - Getting faculty info for course 40690
# 23:19:41 - Completed processing course: 40620
# 23:19:41 -
# Processing course: 40621
# 23:19:41 - Getting faculty info for course 40621
# 23:19:41 - Getting description for course 40694
# 23:19:41 - Completed processing course: 40617
# 23:19:41 -
# Processing course: 40685
# 23:19:41 - Getting faculty info for course 40685
# 23:19:41 - Getting description for course 35641
# 23:19:41 - Getting description for course 40690
# 23:19:41 - Getting description for course 40621
# 23:19:41 - Getting description for course 40685
# 23:19:41 - Getting prerequisites for course 35641
# 23:19:41 - Getting prerequisites for course 40690
# 23:19:41 - Getting prerequisites for course 40694
# 23:19:41 - Getting prerequisites for course 40621
# 23:19:42 - Getting prerequisites for course 40685
# 23:19:42 - Completed processing course: 35641
# 23:19:42 -
# Processing course: 40553
# 23:19:42 - Getting faculty info for course 40553
# 23:19:42 - Completed processing course: 40690
# 23:19:42 -
# Processing course: 41835
# 23:19:42 - Getting faculty info for course 41835
# 23:19:42 - Completed processing course: 40694
# 23:19:42 -
# Processing course: 40695
# 23:19:42 - Getting faculty info for course 40695
# 23:19:42 - Completed processing course: 40621
# 23:19:42 -
# Processing course: 40692
# 23:19:42 - Getting faculty info for course 40692
# 23:19:42 - Completed processing course: 40685
# 23:19:42 - Getting description for course 40553
# 23:19:42 -
# Processing course: 41326
# 23:19:42 - Getting faculty info for course 41326
# 23:19:42 - Progress: 150/500 courses completed (30.0%)
# 23:19:42 - Getting description for course 41835
# 23:19:42 - Getting description for course 40695
# 23:19:42 - Getting description for course 40692
# 23:19:42 - Getting description for course 41326
# 23:19:42 - Getting prerequisites for course 40553
# 23:19:42 - Getting prerequisites for course 41835
# 23:19:42 - Getting prerequisites for course 40692
# 23:19:42 - Getting prerequisites for course 40695
# 23:19:42 - Completed processing course: 40553
# 23:19:42 -
# Processing course: 40618
# 23:19:42 - Getting faculty info for course 40618
# 23:19:42 - Getting prerequisites for course 41326
# 23:19:42 - Completed processing course: 41835
# 23:19:42 -
# Processing course: 40588
# 23:19:42 - Getting faculty info for course 40588
# 23:19:42 - Completed processing course: 40692
# 23:19:42 -
# Processing course: 40693
# 23:19:42 - Getting faculty info for course 40693
# 23:19:42 - Completed processing course: 40695
# 23:19:42 -
# Processing course: 40696
# 23:19:42 - Getting faculty info for course 40696
# 23:19:42 - Getting description for course 40618
# 23:19:42 - Completed processing course: 41326
# 23:19:42 - Getting description for course 40588
# 23:19:42 -
# Processing course: 35643
# 23:19:42 - Getting faculty info for course 35643
# 23:19:42 - Getting description for course 40693
# 23:19:42 - Getting description for course 40696
# 23:19:43 - Getting prerequisites for course 40618
# 23:19:43 - Getting prerequisites for course 40588
# 23:19:43 - Getting description for course 35643
# 23:19:43 - Getting prerequisites for course 40693
# 23:19:43 - Getting prerequisites for course 40696
# 23:19:43 - Completed processing course: 40618
# 23:19:43 -
# Processing course: 40589
# 23:19:43 - Progress: 155/500 courses completed (31.0%)
# 23:19:43 - Getting faculty info for course 40589
# 23:19:43 - Completed processing course: 40588
# 23:19:43 -
# Processing course: 40699
# 23:19:43 - Progress: 160/500 courses completed (32.0%)
# 23:19:43 - Getting faculty info for course 40699
# 23:19:43 - Getting prerequisites for course 35643
# 23:19:43 - Completed processing course: 40693
# 23:19:43 -
# Processing course: 40791
# 23:19:43 - Progress: 165/500 courses completed (33.0%)
# 23:19:43 - Getting faculty info for course 40791
# 23:19:43 - Completed processing course: 40696
# 23:19:43 -
# Processing course: 40790
# 23:19:43 - Getting faculty info for course 40790
# 23:19:43 - Getting description for course 40589
# 23:19:43 - Getting description for course 40699
# 23:19:43 - Completed processing course: 35643
# 23:19:43 -
# Processing course: 40090
# 23:19:43 - Getting faculty info for course 40090
# 23:19:43 - Getting description for course 40791
# 23:19:43 - Getting description for course 40790
# 23:19:43 - Getting prerequisites for course 40699
# 23:19:43 - Getting prerequisites for course 40589
# 23:19:43 - Getting prerequisites for course 40791
# 23:19:43 - Getting prerequisites for course 40790
# 23:19:43 - Completed processing course: 40699
# 23:19:43 -
# Processing course: 40700
# 23:19:43 - Getting faculty info for course 40700
# 23:19:43 - Completed processing course: 40791
# 23:19:43 -
# Processing course: 41165
# 23:19:43 - Getting faculty info for course 41165
# 23:19:43 - Completed processing course: 40589
# 23:19:43 -
# Processing course: 40622
# 23:19:43 - Getting faculty info for course 40622
# 23:19:44 - Getting description for course 40700
# 23:19:44 - Getting prerequisites for course 40700
# 23:19:44 - Completed processing course: 40700
# 23:19:44 -
# Processing course: 40701
# 23:19:44 - Getting faculty info for course 40701
# 23:19:44 - Getting description for course 40701
# 23:19:44 - Getting prerequisites for course 40701
# 23:19:45 - Completed processing course: 40701
# 23:19:45 -
# Processing course: 40702
# 23:19:45 - Getting faculty info for course 40702
# 23:19:47 - Getting description for course 40090
# 23:19:47 - Getting prerequisites for course 40090
# 23:19:48 - Completed processing course: 40790
# 23:19:48 -
# Processing course: 41159
# 23:19:48 - Getting faculty info for course 41159
# 23:19:48 - Getting description for course 41165
# 23:19:48 - Getting description for course 40622
# 23:19:48 - Completed processing course: 40090
# 23:19:48 -
# Processing course: 40091
# 23:19:48 - Getting faculty info for course 40091
# 23:19:48 - Getting description for course 41159
# 23:19:48 - Getting description for course 40702
# 23:19:48 - Getting prerequisites for course 40622
# 23:19:48 - Getting prerequisites for course 41165
# 23:19:48 - Getting description for course 40091
# 23:19:48 - Getting prerequisites for course 41159
# 23:19:48 - Getting prerequisites for course 40702
# 23:19:48 - Completed processing course: 40622
# 23:19:48 -
# Processing course: 40623
# 23:19:48 - Getting faculty info for course 40623
# 23:19:48 - Completed processing course: 41165
# 23:19:48 -
# Processing course: 37038
# 23:19:48 - Getting faculty info for course 37038
# 23:19:48 - Getting prerequisites for course 40091
# 23:19:48 - Completed processing course: 41159
# 23:19:48 -
# Processing course: 40216
# 23:19:48 - Progress: 170/500 courses completed (34.0%)
# 23:19:48 - Getting faculty info for course 40216
# 23:19:48 - Completed processing course: 40702
# 23:19:48 -
# Processing course: 40703
# 23:19:48 - Getting faculty info for course 40703
# 23:19:48 - Getting description for course 40623
# 23:19:48 - Getting description for course 37038
# 23:19:48 - Completed processing course: 40091
# 23:19:48 -
# Processing course: 40555
# 23:19:48 - Getting faculty info for course 40555
# 23:19:48 - Getting description for course 40216
# 23:19:48 - Getting description for course 40703
# 23:19:48 - Getting prerequisites for course 40623
# 23:19:48 - Getting description for course 40555
# 23:19:48 - Getting prerequisites for course 37038
# 23:19:48 - Getting prerequisites for course 40216
# 23:19:49 - Getting prerequisites for course 40703
# 23:19:49 - Completed processing course: 40623
# 23:19:49 -
# Processing course: 40697
# 23:19:49 - Getting faculty info for course 40697
# 23:19:49 - Completed processing course: 37038
# 23:19:49 -
# Processing course: 35644
# 23:19:49 - Getting faculty info for course 35644
# 23:19:49 - Getting prerequisites for course 40555
# 23:19:49 - Completed processing course: 40216
# 23:19:49 -
# Processing course: 40556
# 23:19:49 - Getting faculty info for course 40556
# 23:19:49 - Completed processing course: 40703
# 23:19:49 -
# Processing course: 40704
# 23:19:49 - Progress: 175/500 courses completed (35.0%)
# 23:19:49 - Getting faculty info for course 40704
# 23:19:49 - Getting description for course 35644
# 23:19:49 - Getting description for course 40697
# 23:19:49 - Completed processing course: 40555
# 23:19:49 -
# Processing course: 41219
# 23:19:49 - Progress: 180/500 courses completed (36.0%)
# 23:19:49 - Getting faculty info for course 41219
# 23:19:49 - Getting description for course 40556
# 23:19:49 - Getting description for course 40704
# 23:19:49 - Getting prerequisites for course 35644
# 23:19:49 - Getting prerequisites for course 40697
# 23:19:49 - Getting description for course 41219
# 23:19:49 - Getting prerequisites for course 40556
# 23:19:49 - Getting prerequisites for course 40704
# 23:19:49 - Completed processing course: 35644
# 23:19:49 -
# Processing course: 40215
# 23:19:49 - Getting faculty info for course 40215
# 23:19:49 - Completed processing course: 40697
# 23:19:49 -
# Processing course: 40698
# 23:19:49 - Getting faculty info for course 40698
# 23:19:49 - Getting prerequisites for course 41219
# 23:19:49 - Completed processing course: 40556
# 23:19:49 -
# Processing course: 40590
# 23:19:49 - Getting faculty info for course 40590
# 23:19:49 - Completed processing course: 40704
# 23:19:49 -
# Processing course: 40705
# 23:19:49 - Getting faculty info for course 40705
# 23:19:49 - Getting description for course 40698
# 23:19:49 - Getting description for course 40215
# 23:19:49 - Completed processing course: 41219
# 23:19:49 -
# Processing course: 37044
# 23:19:49 - Getting faculty info for course 37044
# 23:19:49 - Getting description for course 40590
# 23:19:50 - Getting description for course 40705
# 23:19:50 - Getting prerequisites for course 40215
# 23:19:50 - Getting prerequisites for course 40698
# 23:19:50 - Getting description for course 37044
# 23:19:50 - Getting prerequisites for course 40590
# 23:19:50 - Getting prerequisites for course 40705
# 23:19:50 - Completed processing course: 40215
# 23:19:50 -
# Processing course: 40557
# 23:19:50 - Progress: 185/500 courses completed (37.0%)
# 23:19:50 - Getting faculty info for course 40557
# 23:19:50 - Completed processing course: 40590
# 23:19:50 -
# Processing course: 40624
# 23:19:50 - Getting faculty info for course 40624
# 23:19:50 - Completed processing course: 40705
# 23:19:50 -
# Processing course: 40706
# 23:19:50 - Getting faculty info for course 40706
# 23:19:50 - Getting description for course 40557
# 23:19:50 - Getting description for course 40624
# 23:19:50 - Getting description for course 40706
# 23:19:50 - Getting prerequisites for course 40557
# 23:19:50 - Getting prerequisites for course 40624
# ...
# 23:20:35 - Getting prerequisites for course 40752
# 23:20:36 - Getting description for course 40577
# 23:20:36 - Completed processing course: 40752
# 23:20:36 -
# Processing course: 41638
# 23:20:36 - Getting faculty info for course 41638
# 23:20:36 - Getting prerequisites for course 40577
# 23:20:36 - Getting description for course 41638
# 23:20:36 - Completed processing course: 40577
# 23:20:36 -
# Processing course: 40762
# 23:20:36 - Getting faculty info for course 40762
# 23:20:36 - Getting prerequisites for course 41638
# 23:20:36 - Getting description for course 40762
# 23:20:36 - Completed processing course: 41638
# 23:20:36 -
# Processing course: 41471
# 23:20:36 - Getting faculty info for course 41471
# 23:20:36 - Getting prerequisites for course 40762
# 23:20:37 - Getting description for course 41411
# 23:20:37 - Getting description for course 41471
# 23:20:37 - Completed processing course: 40763
# 23:20:37 -
# Processing course: 40764
# 23:20:37 - Getting faculty info for course 40764
# 23:20:37 - Completed processing course: 40762
# 23:20:37 -
# Processing course: 40930
# 23:20:37 - Getting faculty info for course 40930
# 23:20:37 - Getting prerequisites for course 41471
# 23:20:37 - Getting prerequisites for course 41411
# 23:20:37 - Getting description for course 40764
# 23:20:37 - Completed processing course: 41411
# 23:20:37 - Getting description for course 40930
# 23:20:37 -
# Processing course: 41721
# 23:20:37 - Getting faculty info for course 41721
# 23:20:37 - Completed processing course: 41471
# 23:20:37 -
# Processing course: 37702
# 23:20:37 - Progress: 435/500 courses completed (87.0%)
# 23:20:37 - Getting faculty info for course 37702
# 23:20:37 - Getting prerequisites for course 40764
# 23:20:37 - Getting prerequisites for course 40930
# 23:20:37 - Getting description for course 37702
# 23:20:37 - Getting description for course 41721
# 23:20:37 - Completed processing course: 40764
# 23:20:37 -
# Processing course: 40765
# 23:20:37 - Getting faculty info for course 40765
# 23:20:37 - Getting prerequisites for course 37702
# 23:20:37 - Getting prerequisites for course 41721
# 23:20:37 - Completed processing course: 40930
# 23:20:37 -
# Processing course: 40753
# 23:20:37 - Getting faculty info for course 40753
# 23:20:38 - Getting description for course 39815
# 23:20:38 - Getting description for course 40765
# 23:20:38 - Completed processing course: 37702
# 23:20:38 -
# Processing course: 37703
# 23:20:38 - Getting faculty info for course 37703
# 23:20:38 - Completed processing course: 41721
# 23:20:38 -
# Processing course: 37699
# 23:20:38 - Getting faculty info for course 37699
# 23:20:38 - Getting description for course 40753
# 23:20:38 - Getting prerequisites for course 39815
# 23:20:38 - Getting prerequisites for course 40765
# 23:20:38 - Getting description for course 37699
# 23:20:38 - Getting description for course 37703
# 23:20:38 - Getting prerequisites for course 40753
# 23:20:38 - Completed processing course: 39815
# 23:20:38 -
# Processing course: 40489
# 23:20:38 - Getting faculty info for course 40489
# 23:20:38 - Completed processing course: 40765
# 23:20:38 -
# Processing course: 37842
# 23:20:38 - Getting faculty info for course 37842
# 23:20:38 - Getting prerequisites for course 37699
# 23:20:38 - Getting prerequisites for course 37703
# 23:20:38 - Completed processing course: 40753
# 23:20:38 -
# Processing course: 37709
# 23:20:38 - Progress: 440/500 courses completed (88.0%)
# 23:20:38 - Getting faculty info for course 37709
# 23:20:38 - Getting description for course 40489
# 23:20:38 - Getting description for course 37842
# 23:20:38 - Completed processing course: 37703
# 23:20:38 -
# Processing course: 37706
# 23:20:38 - Getting faculty info for course 37706
# 23:20:38 - Completed processing course: 37699
# 23:20:38 - Getting description for course 37709
# 23:20:38 -
# Processing course: 37700
# 23:20:38 - Getting faculty info for course 37700
# 23:20:38 - Getting prerequisites for course 40489
# 23:20:38 - Getting prerequisites for course 37842
# 23:20:38 - Getting description for course 37706
# 23:20:38 - Getting prerequisites for course 37709
# 23:20:39 - Getting description for course 37700
# 23:20:39 - Completed processing course: 40489
# 23:20:39 -
# Processing course: 37061
# 23:20:39 - Getting faculty info for course 37061
# 23:20:39 - Completed processing course: 37842
# 23:20:39 -
# Processing course: 41366
# 23:20:39 - Getting faculty info for course 41366
# 23:20:39 - Completed processing course: 37709
# 23:20:39 - Getting prerequisites for course 37706
# 23:20:39 -
# Processing course: 37711
# 23:20:39 - Getting faculty info for course 37711
# 23:20:39 - Getting prerequisites for course 37700
# 23:20:39 - Getting description for course 37061
# 23:20:39 - Getting description for course 41366
# 23:20:39 - Completed processing course: 37706
# 23:20:39 - Completed processing course: 37700
# 23:20:39 - Getting description for course 37711
# 23:20:39 -
# Processing course: 37707
# 23:20:39 -
# Processing course: 37701
# 23:20:39 - Getting faculty info for course 37707
# 23:20:39 - Getting faculty info for course 37701
# 23:20:39 - Getting prerequisites for course 37061
# 23:20:39 - Getting prerequisites for course 41366
# 23:20:39 - Getting prerequisites for course 37711
# 23:20:39 - Getting description for course 37707
# 23:20:39 - Getting description for course 37701
# 23:20:39 - Completed processing course: 37061
# 23:20:39 -
# Processing course: 37062
# 23:20:39 - Getting faculty info for course 37062
# 23:20:39 - Completed processing course: 41366
# 23:20:39 -
# Processing course: 37714
# 23:20:39 - Progress: 445/500 courses completed (89.0%)
# 23:20:39 - Getting faculty info for course 37714
# 23:20:39 - Completed processing course: 37711
# 23:20:39 -
# Processing course: 37710
# 23:20:39 - Getting faculty info for course 37710
# 23:20:39 - Getting prerequisites for course 37707
# 23:20:39 - Getting prerequisites for course 37701
# 23:20:39 - Getting description for course 37062
# 23:20:39 - Getting description for course 37714
# 23:20:40 - Getting description for course 37710
# 23:20:40 - Completed processing course: 37707
# 23:20:40 -
# Processing course: 37708
# 23:20:40 - Getting faculty info for course 37708
# 23:20:40 - Completed processing course: 37701
# 23:20:40 -
# Processing course: 37719
# 23:20:40 - Progress: 450/500 courses completed (90.0%)
# 23:20:40 - Getting faculty info for course 37719
# 23:20:40 - Getting prerequisites for course 37062
# 23:20:40 - Getting prerequisites for course 37714
# 23:20:40 - Getting description for course 37719
# 23:20:40 - Getting description for course 37708
# 23:20:40 - Getting prerequisites for course 37710
# 23:20:40 - Completed processing course: 37062
# 23:20:40 -
# Processing course: 37724
# 23:20:40 - Progress: 455/500 courses completed (91.0%)
# 23:20:40 - Getting faculty info for course 37724
# 23:20:40 - Completed processing course: 37714
# 23:20:40 -
# Processing course: 37715
# 23:20:40 - Getting faculty info for course 37715
# 23:20:40 - Getting prerequisites for course 37708
# 23:20:40 - Getting prerequisites for course 37719
# 23:20:40 - Completed processing course: 37710
# 23:20:40 -
# Processing course: 37712
# 23:20:40 - Getting faculty info for course 37712
# 23:20:40 - Getting description for course 37724
# 23:20:40 - Getting description for course 37715
# 23:20:40 - Getting description for course 37712
# 23:20:40 - Completed processing course: 37708
# 23:20:40 - Completed processing course: 37719
# 23:20:40 -
# Processing course: 37729
# 23:20:40 - Progress: 460/500 courses completed (92.0%)
# 23:20:40 -
# Processing course: 37720
# 23:20:40 - Getting faculty info for course 37729
# 23:20:40 - Getting faculty info for course 37720
# 23:20:40 - Getting prerequisites for course 37724
# 23:20:40 - Getting prerequisites for course 37715
# 23:20:40 - Getting prerequisites for course 37712
# 23:20:40 - Getting description for course 37720
# 23:20:40 - Getting description for course 37729
# 23:20:41 - Completed processing course: 37724
# 23:20:41 - Completed processing course: 37715
# 23:20:41 -
# Processing course: 37725
# 23:20:41 -
# Processing course: 37716
# 23:20:41 - Getting faculty info for course 37725
# 23:20:41 - Getting faculty info for course 37716
# 23:20:41 - Completed processing course: 37712
# 23:20:41 -
# Processing course: 37713
# 23:20:41 - Getting faculty info for course 37713
# 23:20:41 - Getting prerequisites for course 37729
# 23:20:41 - Getting prerequisites for course 37720
# 23:20:41 - Getting description for course 37725
# 23:20:41 - Getting description for course 37716
# 23:20:41 - Getting description for course 37713
# 23:20:41 - Completed processing course: 37720
# 23:20:41 - Completed processing course: 37729
# 23:20:41 -
# Processing course: 37721
# 23:20:41 -
# Processing course: 37730
# 23:20:41 - Getting faculty info for course 37721
# 23:20:41 - Getting faculty info for course 37730
# 23:20:41 - Getting prerequisites for course 37725
# 23:20:41 - Getting prerequisites for course 37716
# 23:20:41 - Getting prerequisites for course 37713
# 23:20:41 - Getting description for course 37730
# 23:20:41 - Getting description for course 37721
# 23:20:41 - Completed processing course: 37716
# 23:20:41 - Completed processing course: 37725
# 23:20:41 -
# Processing course: 37717
# 23:20:41 -
# Processing course: 37726
# 23:20:41 - Getting faculty info for course 37717
# 23:20:41 - Getting faculty info for course 37726
# 23:20:41 - Completed processing course: 37713
# 23:20:41 -
# Processing course: 37734
# 23:20:41 - Progress: 465/500 courses completed (93.0%)
# 23:20:41 - Getting faculty info for course 37734
# 23:20:41 - Getting prerequisites for course 37721
# 23:20:41 - Getting prerequisites for course 37730
# 23:20:41 - Getting description for course 37717
# 23:20:41 - Getting description for course 37726
# 23:20:41 - Getting description for course 37734
# 23:20:42 - Completed processing course: 37721
# 23:20:42 -
# Processing course: 37722
# 23:20:42 - Getting faculty info for course 37722
# 23:20:42 - Completed processing course: 37730
# 23:20:42 -
# Processing course: 37731
# 23:20:42 - Getting faculty info for course 37731
# 23:20:42 - Getting prerequisites for course 37717
# 23:20:42 - Getting prerequisites for course 37726
# 23:20:42 - Getting prerequisites for course 37734
# 23:20:42 - Getting description for course 37722
# 23:20:42 - Getting description for course 37731
# 23:20:42 - Completed processing course: 37726
# 23:20:42 - Completed processing course: 37717
# 23:20:42 - Completed processing course: 37734
# 23:20:42 -
# Processing course: 37727
# 23:20:42 -
# Processing course: 37718
# 23:20:42 -
# Processing course: 37735
# 23:20:42 - Getting faculty info for course 37727
# 23:20:42 - Getting faculty info for course 37718
# 23:20:42 - Getting faculty info for course 37735
# 23:20:42 - Getting prerequisites for course 37722
# 23:20:42 - Getting prerequisites for course 37731
# 23:20:42 - Getting description for course 37735
# 23:20:42 - Getting description for course 37727
# 23:20:42 - Completed processing course: 37731
# 23:20:42 - Completed processing course: 37722
# 23:20:42 - Getting description for course 37718
# 23:20:42 -
# Processing course: 37732
# 23:20:42 -
# Processing course: 37723
# 23:20:42 - Getting faculty info for course 37732
# 23:20:42 - Getting faculty info for course 37723
# 23:20:42 - Getting prerequisites for course 37735
# 23:20:42 - Getting prerequisites for course 37727
# 23:20:42 - Getting description for course 37723
# 23:20:42 - Getting description for course 37732
# 23:20:42 - Getting prerequisites for course 37718
# 23:20:43 - Completed processing course: 37735
# 23:20:43 -
# Processing course: 37736
# 23:20:43 - Getting faculty info for course 37736
# 23:20:43 - Completed processing course: 37727
# 23:20:43 -
# Processing course: 37728
# 23:20:43 - Getting faculty info for course 37728
# 23:20:43 - Getting prerequisites for course 37723
# 23:20:43 - Completed processing course: 37718
# 23:20:43 -
# Processing course: 37739
# 23:20:43 - Progress: 470/500 courses completed (94.0%)
# 23:20:43 - Getting faculty info for course 37739
# 23:20:43 - Getting prerequisites for course 37732
# 23:20:43 - Getting description for course 37736
# 23:20:43 - Getting description for course 37728
# 23:20:43 - Completed processing course: 37723
# 23:20:43 - Completed processing course: 37732
# 23:20:43 -
# Processing course: 37744
# 23:20:43 - Progress: 475/500 courses completed (95.0%)
# 23:20:43 -
# Processing course: 37733
# 23:20:43 - Getting faculty info for course 37744
# 23:20:43 - Getting faculty info for course 37733
# 23:20:43 - Getting description for course 37739
# 23:20:43 - Getting prerequisites for course 37736
# 23:20:43 - Getting prerequisites for course 37728
# 23:20:43 - Getting description for course 37744
# 23:20:43 - Getting description for course 37733
# 23:20:43 - Getting prerequisites for course 37739
# 23:20:43 - Completed processing course: 37736
# 23:20:43 -
# Processing course: 37737
# 23:20:43 - Getting faculty info for course 37737
# 23:20:43 - Completed processing course: 37728
# 23:20:43 - Progress: 480/500 courses completed (96.0%)
# 23:20:43 - Getting prerequisites for course 37744
# 23:20:43 - Completed processing course: 37739
# 23:20:43 -
# Processing course: 37740
# 23:20:43 - Getting faculty info for course 37740
# 23:20:43 - Getting prerequisites for course 37733
# 23:20:43 - Getting description for course 37737
# 23:20:43 - Completed processing course: 37744
# 23:20:43 -
# Processing course: 37745
# 23:20:43 - Getting faculty info for course 37745
# 23:20:43 - Getting description for course 37740
# 23:20:43 - Completed processing course: 37733
# 23:20:43 - Progress: 485/500 courses completed (97.0%)
# 23:20:44 - Getting prerequisites for course 37737
# 23:20:44 - Getting description for course 37745
# 23:20:44 - Getting prerequisites for course 37740
# 23:20:44 - Completed processing course: 37737
# 23:20:44 -
# Processing course: 37738
# 23:20:44 - Getting faculty info for course 37738
# 23:20:44 - Getting prerequisites for course 37745
# 23:20:44 - Completed processing course: 37740
# 23:20:44 -
# Processing course: 37741
# 23:20:44 - Getting faculty info for course 37741
# 23:20:44 - Getting description for course 37738
# 23:20:44 - Completed processing course: 37745
# 23:20:44 -
# Processing course: 37746
# 23:20:44 - Getting faculty info for course 37746
# 23:20:44 - Getting description for course 37741
# 23:20:44 - Getting prerequisites for course 37738
# 23:20:44 - Getting description for course 37746
# 23:20:44 - Getting prerequisites for course 37741
# 23:20:44 - Completed processing course: 37738
# 23:20:44 - Progress: 490/500 courses completed (98.0%)
# 23:20:44 - Getting prerequisites for course 37746
# 23:20:45 - Completed processing course: 37741
# 23:20:45 -
# Processing course: 37742
# 23:20:45 - Getting faculty info for course 37742
# 23:20:45 - Completed processing course: 37746
# 23:20:45 -
# Processing course: 37747
# 23:20:45 - Getting faculty info for course 37747
# 23:20:45 - Getting description for course 37742
# 23:20:45 - Getting description for course 37747
# 23:20:45 - Getting prerequisites for course 37742
# 23:20:45 - Getting prerequisites for course 37747
# 23:20:45 - Completed processing course: 37742
# 23:20:45 -
# Processing course: 37743
# 23:20:45 - Getting faculty info for course 37743
# 23:20:45 - Completed processing course: 37747
# 23:20:45 -
# Processing course: 37748
# 23:20:45 - Getting faculty info for course 37748
# 23:20:45 - Getting description for course 37743
# 23:20:45 - Getting description for course 37748
# 23:20:46 - Getting prerequisites for course 37743
# 23:20:46 - Completed processing course: 37743
# 23:20:46 - Progress: 495/500 courses completed (99.0%)
# 23:20:46 - Getting prerequisites for course 37748
# 23:20:46 - Completed processing course: 37748
# 23:20:46 - Progress: 500/500 courses completed (100.0%)
# === Step 4: Saving Data ===
#
# Successfully saved data for 500 courses to courses.csv
#
# Sample of collected data:
#      CRN                           Course Title       Faculty Name    Days
# 0  34154  Computer Science and Its Applications   Lieberherr, Karl
# 1  32828                        Lab for CS 1100   Lieberherr, Karl  Friday
# 2  32829                        Lab for CS 1100   Lieberherr, Karl  Friday
# 3  32830                        Lab for CS 1100   Lieberherr, Karl  Friday
# 4  34155                     First Year Seminar  Wassinger, Claire
#
# === Course Data Collection Complete ===
